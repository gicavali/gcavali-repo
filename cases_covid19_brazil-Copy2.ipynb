# %%
#!pip install bezier
#!pip install networkx==2.6.2

import copy
import getopt
import math
import networkx as nx
import operator
import os
import random
import sys
from scipy import stats
import seaborn as sns
import time
import pandas as pd
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import scipy.optimize as opt
from scipy.misc import derivative
from matplotlib.collections import LineCollection
from scipy.stats import pearsonr
from networkx.algorithms import tree

try:
    import bezier
except:
    pass
# %matplotlib inline

# %%
palette = sns.color_palette("flare")
palette
# Out:
# [(0.9155979, 0.55210684, 0.42070204),
#  (0.888292, 0.40830288, 0.36223756),
#  (0.81942908, 0.28911553, 0.38102921),
#  (0.69226314, 0.23413578, 0.42480327),
#  (0.56041794, 0.19845221, 0.44207535),
#  (0.42355299, 0.16934709, 0.42581586)]

# %%
try:
    from google.colab import drive

    drive.mount("/content/gdrive")
except:
    pass

# %%
def clean(series):
    series = series.str.upper()
    series = series.str.replace("Á", "A")
    series = series.str.replace("É", "E")
    series = series.str.replace("Ú", "U")
    series = series.str.replace("Ó", "O")
    series = series.str.replace("Í", "I")
    series = series.str.replace("Ã", "A")
    series = series.str.replace("Õ", "O")
    series = series.str.replace("Ô", "O")
    series = series.str.replace("Â", "A")
    series = series.str.replace("Ê", "E")
    series = series.str.replace("Ç", "C")
    series = series.str.replace("-", "")
    series = series.str.replace("'", "")
    series = series.str.upper()
    return series


def clean_str(series):
    series = series.upper()
    series = series.replace("Á", "A")
    series = series.replace("É", "E")
    series = series.replace("Ú", "U")
    series = series.replace("Ó", "O")
    series = series.replace("Í", "I")
    series = series.replace("Ã", "A")
    series = series.replace("Õ", "O")
    series = series.replace("Ô", "O")
    series = series.replace("Â", "A")
    series = series.replace("Ê", "E")
    series = series.replace("Ç", "C")
    series = series.replace("-", "")
    series = series.replace("'", "")
    return series

# %%
try:
    popDf = pd.read_excel(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/MUNIC_2019.xlsx"
    )
except:
    popDf = pd.read_excel("MUNIC_2019.xlsx")
popDf["NOME MUNIC"] = clean(popDf["NOME MUNIC"])
popDf.head(2)
# Out:
#     CodMun     REGIAO  COD UF  UF                 NOME MUNIC  POP EST  \
# 0  1100015  1 - Norte      11  RO  ALTA FLORESTA DOESTE (RO)    22945
# 1  1100023  1 - Norte      11  RO             ARIQUEMES (RO)   107863
#
#               CLASSE POP
# 0    4 - 20001 até 50000
# 1  6 - 100001 até 500000

# %%
try:
    casosDf = pd.read_csv(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/caso_full.csv"
    )
except:
    casosDf = pd.read_csv("caso_full.csv")

casosStDf = casosDf[casosDf.place_type == "state"]
casosDf = casosDf[casosDf.place_type == "city"]
casosDf.city = clean(casosDf.city)
casosDf["city_state"] = casosDf.city + " (" + casosDf.state + ")"
casosDf.head(2)  # casos por cidade
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  RIO BRANCO       1200401.0  2020-03-17                202012
# 2  RIO BRANCO       1200401.0  2020-03-18                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 2              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                         3                                        0.72566
# 2                         3                                        0.72566
#
#   last_available_date  last_available_death_rate  last_available_deaths  \
# 0          2020-03-17                        0.0                      0
# 2          2020-03-18                        0.0                      0
#
#    order_for_place place_type state  new_confirmed  new_deaths  \
# 0                1       city    AC              3           0
# 2                2       city    AC              0           0
#
#         city_state
# 0  RIO BRANCO (AC)
# 2  RIO BRANCO (AC)

# %%
casosStDf.head(2)  # casos por estado
# Out:
#   city  city_ibge_code        date  epidemiological_week  \
# 1  NaN            12.0  2020-03-17                202012
# 3  NaN            12.0  2020-03-18                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 1              894470.0                   881935.0    False        False
# 3              894470.0                   881935.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 1                         3                                        0.33539
# 3                         3                                        0.33539
#
#   last_available_date  last_available_death_rate  last_available_deaths  \
# 1          2020-03-17                        0.0                      0
# 3          2020-03-18                        0.0                      0
#
#    order_for_place place_type state  new_confirmed  new_deaths
# 1                1      state    AC              3           0
# 3                2      state    AC              0           0

# %%
epiweekDf = casosDf[["date", "epidemiological_week"]].drop_duplicates()
print(len(epiweekDf), "semanas epidemiológicas")
epiweekDf.tail(2)  # semanas epidemiológicas
# Out:
# 692 semanas epidemiológicas
#                date  epidemiological_week
# 2970939  2020-03-03                202010
# 2970941  2020-03-04                202010

# %%
casosDf = pd.merge(
    left=casosDf, right=popDf, how="left", left_on="city_state", right_on="NOME MUNIC"
)
print(casosDf["CLASSE POP"].value_counts())
# Out:
# 3 - 10001 até 20000      828311
# 1 - Até 5000             739884
# 2 - 5001 até 10000       723726
# 4 - 20001 até 50000      693037
# 5 - 50001 até 100000     225184
# 6 - 100001 até 500000    181618
# 7 - Maior que 500000      32236
# Name: CLASSE POP, dtype: int64

# %%
def group_data(Df, list):
    GroupDf = (
        Df.groupby(list)
        .agg(
            {
                "last_available_confirmed": "sum",
                "last_available_confirmed_per_100k_inhabitants": "mean",
                "new_confirmed": "sum",
                "last_available_deaths": "sum",
                "new_deaths": "sum",
                "estimated_population": "mean",
            }
        )
        .reset_index()
    )
    return GroupDf


def create_variable(Df, level, x1, x2):
    Df["confirmed_percent"] = Df.last_available_confirmed / Df.estimated_population
    Df["new_deaths_percent"] = Df.groupby(level)["new_deaths"].pct_change()
    Df["new_confirmed_percent"] = Df.groupby(level)["new_confirmed"].pct_change()
    Df["new_deaths_percent"] = Df["new_deaths_percent"].replace(
        [np.inf, -np.inf, np.nan, None], None
    )
    Df["new_confirmed_percent"] = Df["new_confirmed_percent"].replace(
        [np.inf, -np.inf, np.nan, None], None
    )
    Df["decrease_deaths"] = Df["new_deaths_percent"] <= x1
    Df["stability_deaths"] = (Df["new_deaths_percent"] > x1) & (
        Df["new_deaths_percent"] <= x2
    )
    Df["increase_deaths"] = Df["new_deaths_percent"] > x2
    Df["decrease_cases"] = Df["new_confirmed_percent"] < x1
    Df["stability_cases"] = (Df["new_confirmed_percent"] > x1) & (
        Df["new_confirmed_percent"] <= x2
    )
    Df["increase_cases"] = Df["new_confirmed_percent"] > x2
    Df["confirmed_t1"] = [None] + list(Df["last_available_confirmed"][:-1])
    Df["confirmed_t2"] = [None, None] + list(Df["last_available_confirmed"][:-2])
    Df["new_confirmed_t1"] = [None] + list(Df["new_confirmed"][:-1])
    Df["new_confirmed_t2"] = [None, None] + list(Df["new_confirmed"][:-2])
    Df["new_confirmed_t3"] = [None, None, None] + list(Df["new_confirmed"][:-3])
    Df["new_confirmed_t4"] = [None, None, None, None] + list(Df["new_confirmed"][:-4])
    Df["new_confirmed_t5"] = [None, None, None, None, None] + list(
        Df["new_confirmed"][:-5]
    )
    Df["new_confirmed_t6"] = [None, None, None, None, None, None] + list(
        Df["new_confirmed"][:-6]
    )
    return Df


def group_time(Df, level_time, level_city):
    GroupDf = Df.groupby(level_time).agg(
        {
            level_city: "count",
            "decrease_deaths": "sum",
            "stability_deaths": "sum",
            "increase_deaths": "sum",
            "decrease_cases": "sum",
            "stability_cases": "sum",
            "increase_cases": "sum",
        }
    )
    GroupDf["decrease_deaths_percent"] = (
        GroupDf["decrease_deaths"] / GroupDf[level_city]
    )
    GroupDf["stability_deaths_percent"] = (
        GroupDf["stability_deaths"] / GroupDf[level_city]
    )
    GroupDf["increase_deaths_percent"] = (
        GroupDf["increase_deaths"] / GroupDf[level_city]
    )
    GroupDf["decrease_cases_percent"] = GroupDf["decrease_cases"] / GroupDf[level_city]
    GroupDf["stability_cases_percent"] = (
        GroupDf["stability_cases"] / GroupDf[level_city]
    )
    GroupDf["increase_cases_percent"] = GroupDf["increase_cases"] / GroupDf[level_city]
    return GroupDf

# %%
casosStGroupDf = group_data(casosStDf, ["state", "epidemiological_week"])
casosStGroupDf = create_variable(casosStGroupDf, "state", -0.01, 0.10)
casosStGroupDf.head(2)
# Out:
#   state  epidemiological_week  last_available_confirmed  \
# 0    AC                202012                        28
# 1    AC                202013                       145
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                       0.626068             11
# 1                                       2.315819             14
#
#    last_available_deaths  new_deaths  estimated_population  confirmed_percent  \
# 0                      0           0              894470.0           0.000031
# 1                      0           0              894470.0           0.000162
#
#    new_deaths_percent  ...  stability_cases  increase_cases  confirmed_t1  \
# 0                 NaN  ...            False           False           NaN
# 1                 NaN  ...            False            True          28.0
#
#    confirmed_t2  new_confirmed_t1  new_confirmed_t2  new_confirmed_t3  \
# 0           NaN               NaN               NaN               NaN
# 1           NaN              11.0               NaN               NaN
#
#    new_confirmed_t4  new_confirmed_t5  new_confirmed_t6
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
#
# [2 rows x 25 columns]

# %%
casosGroupDf = group_data(casosDf, ["city_state", "epidemiological_week"])
casosGroupDf = create_variable(casosGroupDf, "city_state", -0.01, 0.10)
casosGroupDf.head(2)
# Out:
#              city_state  epidemiological_week  last_available_confirmed  \
# 0  ABADIA DE GOIAS (GO)                202021                        16
# 1  ABADIA DE GOIAS (GO)                202022                        41
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                      59.537100              5
# 1                                      65.384496              1
#
#    last_available_deaths  new_deaths  estimated_population  confirmed_percent  \
# 0                      0           0                8958.0           0.001786
# 1                      0           0                8958.0           0.004577
#
#    new_deaths_percent  ...  stability_cases  increase_cases  confirmed_t1  \
# 0                 NaN  ...            False           False           NaN
# 1                 NaN  ...            False           False          16.0
#
#    confirmed_t2  new_confirmed_t1  new_confirmed_t2  new_confirmed_t3  \
# 0           NaN               NaN               NaN               NaN
# 1           NaN               5.0               NaN               NaN
#
#    new_confirmed_t4  new_confirmed_t5  new_confirmed_t6
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
#
# [2 rows x 25 columns]

# %%
casosGroupDf.groupby("epidemiological_week")["new_confirmed"].sum().to_csv(
    "cases_week.csv"
)

# %%
casosEpiWeekDf = group_time(casosGroupDf, "epidemiological_week", "city_state")
casosEpiWeekDf.head()
# Out:
#                       city_state  decrease_deaths  stability_deaths  \
# epidemiological_week
# 202009                         1                1                 0
# 202010                         6                6                 0
# 202011                        31               31                 0
# 202012                       142              142                 0
# 202013                       313              312                 0
#
#                       increase_deaths  decrease_cases  stability_cases  \
# epidemiological_week
# 202009                              0               1                0
# 202010                              0               5                0
# 202011                              0              27                1
# 202012                              0             118                5
# 202013                              1             230               18
#
#                       increase_cases  decrease_deaths_percent  \
# epidemiological_week
# 202009                             0                 1.000000
# 202010                             1                 1.000000
# 202011                             3                 1.000000
# 202012                            19                 1.000000
# 202013                            65                 0.996805
#
#                       stability_deaths_percent  increase_deaths_percent  \
# epidemiological_week
# 202009                                     0.0                 0.000000
# 202010                                     0.0                 0.000000
# 202011                                     0.0                 0.000000
# 202012                                     0.0                 0.000000
# 202013                                     0.0                 0.003195
#
#                       decrease_cases_percent  stability_cases_percent  \
# epidemiological_week
# 202009                              1.000000                 0.000000
# 202010                              0.833333                 0.000000
# 202011                              0.870968                 0.032258
# 202012                              0.830986                 0.035211
# 202013                              0.734824                 0.057508
#
#                       increase_cases_percent
# epidemiological_week
# 202009                              0.000000
# 202010                              0.166667
# 202011                              0.096774
# 202012                              0.133803
# 202013                              0.207668

# %%
casosStEpiWeekDf = group_time(casosStGroupDf, "epidemiological_week", "state")
casosStEpiWeekDf.head()
# Out:
#                       state  decrease_deaths  stability_deaths  \
# epidemiological_week
# 202009                    1                1                 0
# 202010                    5                5                 0
# 202011                   17               17                 0
# 202012                   27               26                 0
# 202013                   27               24                 0
#
#                       increase_deaths  decrease_cases  stability_cases  \
# epidemiological_week
# 202009                              0               1                0
# 202010                              0               4                0
# 202011                              0              12                0
# 202012                              0              10                0
# 202013                              2               1                2
#
#                       increase_cases  decrease_deaths_percent  \
# epidemiological_week
# 202009                             0                 1.000000
# 202010                             1                 1.000000
# 202011                             5                 1.000000
# 202012                            16                 0.962963
# 202013                            24                 0.888889
#
#                       stability_deaths_percent  increase_deaths_percent  \
# epidemiological_week
# 202009                                     0.0                 0.000000
# 202010                                     0.0                 0.000000
# 202011                                     0.0                 0.000000
# 202012                                     0.0                 0.000000
# 202013                                     0.0                 0.074074
#
#                       decrease_cases_percent  stability_cases_percent  \
# epidemiological_week
# 202009                              1.000000                 0.000000
# 202010                              0.800000                 0.000000
# 202011                              0.705882                 0.000000
# 202012                              0.370370                 0.000000
# 202013                              0.037037                 0.074074
#
#                       increase_cases_percent
# epidemiological_week
# 202009                              0.000000
# 202010                              0.200000
# 202011                              0.294118
# 202012                              0.592593
# 202013                              0.888889

# %%
def create_network(path):
    """
    Create a NetworkX graph object using the airport and route databases.
    Args:
        nodes: The file path to the nodes .csv file.
        edeges: The file path to the edges .csv file.
    Returns:
        G: A NetworkX DiGraph object populated with the nodes and edges assigned
           by the data files from the arguments.
    """
    print("Creating network.")
    G = nx.read_gexf(path)

    # Add pos attribute in nodes
    for node in G.nodes():
        long = G.nodes[node]["long"]
        lat = G.nodes[node]["lat"]
        loc = (long, lat)
        node_dict = {node: loc}
        nx.set_node_attributes(G, node_dict, "pos")

    # Calculate the edge weights
    print("\tCalculating edge weights", end="")
    degree_network = nx.Graph(G)
    ldegree = degree_network.degree
    for i, j in G.edges():
        degree_sum = ldegree[i] + ldegree[j]
        G[i][j]["weight"] = degree_sum

    print("\t\t\t\t[Done]")

    G = nx.relabel_nodes(G, clean_str)

    # Calculate the edge distances
    print("\tCalculating edge distance", end="")
    G = calculate_distance(G)
    print("\t\t\t\t[Done]")

    # Add clustering data
    print("\tCalculating clustering coefficents", end="")
    cluster_network = nx.Graph(G)
    lcluster = nx.clustering(cluster_network)
    for i, j in G.edges():
        cluster_sum = lcluster[i] + lcluster[j]
        G[i][j]["cluster"] = cluster_sum
    print("\t\t\t[Done]")

    return G

# %%
from math import cos, asin, sqrt, pi


def distance(lat1, lon1, lat2, lon2):
    p = pi / 180
    a = (
        0.5
        - cos((lat2 - lat1) * p) / 2
        + cos(lat1 * p) * cos(lat2 * p) * (1 - cos((lon2 - lon1) * p)) / 2
    )
    return 12742 * asin(sqrt(a))


def calculate_distance(input_network):
    """
    Add weights to the edges of a network based on the degrees of the connecting
    verticies, and return the network.
    Args:
        input_network: A NetworkX graph object
    Returns:
        G: A weighted NetworkX graph object.
    """

    G = input_network.copy()

    # Add weights to edges
    for node, successor in G.edges():
        dist = distance(
            G.nodes[node]["lat"],
            G.nodes[node]["long"],
            G.nodes[successor]["lat"],
            G.nodes[successor]["long"],
        )
        edge_dict = {(node, successor): dist}
        nx.set_edge_attributes(G, edge_dict, "distance")

    return G

# %%
def calculate_weights(input_network):
    """
    Add weights to the edges of a network based on the degrees of the connecting
    verticies, and return the network.
    Args:
        input_network: A NetworkX graph object
    Returns:
        G: A weighted NetworkX graph object.
    """

    G = input_network.copy()

    # Add weights to edges
    for node in G.nodes():
        successors = G.neighbors(node)
        weights = {}

        # Calculate the total out degree of all succs
        total_degree = 0
        for successor in successors:
            weights[successor] = G.degree(successor)

        largest_weight = max(weights.items())[1]
        smallest_weight = min(weights.items())[1]

        successors = G.neighbors(node)
        for successor in successors:
            if largest_weight == smallest_weight:
                relative_weight = 0
            else:
                relative_weight = (weights[successor] - smallest_weight) / (
                    largest_weight - smallest_weight
                )
            G[node][successor]["weight"] = relative_weight

    return G

# %%
def curved_edges(G, pos, dist_ratio=0.2, bezier_precision=20, polarity="random"):
    # Get nodes into np array
    edges = np.array(G.edges())
    l = edges.shape[0]

    if polarity == "random":
        # Random polarity of curve
        rnd = np.where(np.random.randint(2, size=l) == 0, -1, 1)
    else:
        # Create a fixed (hashed) polarity column in the case we use fixed polarity
        # This is useful, e.g., for animations
        rnd = np.where(
            np.mod(np.vectorize(hash)(edges[:, 0]) + np.vectorize(hash)(edges[:, 1]), 2)
            == 0,
            -1,
            1,
        )

    # Coordinates (x,y) of both nodes for each edge
    # e.g., https://stackoverflow.com/questions/16992713/translate-every-element-in-numpy-array-according-to-key
    # Note the np.vectorize method doesn't work for all node position dictionaries for some reason
    u, inv = np.unique(edges, return_inverse=True)
    coords = np.array([pos[x] for x in u])[inv].reshape(
        [edges.shape[0], 2, edges.shape[1]]
    )
    coords_node1 = coords[:, 0, :]
    coords_node2 = coords[:, 1, :]

    # Swap node1/node2 allocations to make sure the directionality works correctly
    should_swap = coords_node1[:, 0] > coords_node2[:, 0]
    coords_node1[should_swap], coords_node2[should_swap] = (
        coords_node2[should_swap],
        coords_node1[should_swap],
    )

    # Distance for control points
    dist = dist_ratio * np.sqrt(np.sum((coords_node1 - coords_node2) ** 2, axis=1))

    # Gradients of line connecting node & perpendicular
    m1 = (coords_node2[:, 1] - coords_node1[:, 1]) / (
        coords_node2[:, 0] - coords_node1[:, 0]
    )
    m2 = -1 / m1

    # Temporary points along the line which connects two nodes
    # e.g., https://math.stackexchange.com/questions/656500/given-a-point-slope-and-a-distance-along-that-slope-easily-find-a-second-p
    t1 = dist / np.sqrt(1 + m1**2)
    v1 = np.array([np.ones(l), m1])
    coords_node1_displace = coords_node1 + (v1 * t1).T
    coords_node2_displace = coords_node2 - (v1 * t1).T

    # Control points, same distance but along perpendicular line
    # rnd gives the 'polarity' to determine which side of the line the curve should arc
    t2 = dist / np.sqrt(1 + m2**2)
    v2 = np.array([np.ones(len(edges)), m2])
    coords_node1_ctrl = coords_node1_displace + (rnd * v2 * t2).T
    coords_node2_ctrl = coords_node2_displace + (rnd * v2 * t2).T

    # Combine all these four (x,y) columns into a 'node matrix'
    node_matrix = np.array(
        [coords_node1, coords_node1_ctrl, coords_node2_ctrl, coords_node2]
    )

    # Create the Bezier curves and store them in a list
    curveplots = []
    for i in range(l):
        nodes = node_matrix[:, i, :].T
        curveplots.append(
            bezier.Curve(nodes, degree=2)
            .evaluate_multi(np.linspace(0, 1, bezier_precision))
            .T
        )

    # Return an array of these curves
    curves = np.array(curveplots)

    return curves

# %%
try:
    G = create_network(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/grafo_cidades_aeroportos.gexf"
    )
except:
    G = create_network("grafo_cidades_aeroportos.gexf")
G.remove_edges_from(nx.selfloop_edges(G))
# Out:
# Creating network.
# Creating network.
# 	Calculating edge weights				[Done]
# 	Calculating edge distance				[Done]
# 	Calculating clustering coefficents			[Done]

# %%
epi_week = list(set(casosGroupDf.epidemiological_week.tolist()))
edges = [str(x) for x in list(G.edges())]
# edges = [str((u,v)) for u,v,e in G.edges(data=True) if e['aereo'] == 'sim']
new_confirmed_sum_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_diff_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_percent_avg_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_percent_diff_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_corr_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_avg_df = pd.DataFrame(columns=edges, index=epi_week)
new_confirmed_sum_df.loc[202009, "('CACOAL (RO)', 'VARZEA GRANDE (MT)')"]
# Out:
# nan

# %%
aero_edges = [(u, v) for u, v, e in G.edges(data=True) if e["aereo"] == "sim"]

# %%
casosGroupDf.head()
# Out:
#              city_state  epidemiological_week  last_available_confirmed  \
# 0  ABADIA DE GOIAS (GO)                202021                        16
# 1  ABADIA DE GOIAS (GO)                202022                        41
# 2  ABADIA DE GOIAS (GO)                202023                        50
# 3  ABADIA DE GOIAS (GO)                202024                        80
# 4  ABADIA DE GOIAS (GO)                202025                       142
#
#    last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                      59.537100              5
# 1                                      65.384496              1
# 2                                      79.737186              1
# 3                                     127.579499              7
# 4                                     226.453607              8
#
#    last_available_deaths  new_deaths  estimated_population  confirmed_percent  \
# 0                      0           0                8958.0           0.001786
# 1                      0           0                8958.0           0.004577
# 2                      0           0                8958.0           0.005582
# 3                      0           0                8958.0           0.008931
# 4                      0           0                8958.0           0.015852
#
#    new_deaths_percent  ...  stability_cases  increase_cases  confirmed_t1  \
# 0                 NaN  ...            False           False           NaN
# 1                 NaN  ...            False           False          16.0
# 2                 NaN  ...             True           False          41.0
# 3                 NaN  ...            False            True          50.0
# 4                 NaN  ...            False            True          80.0
#
#    confirmed_t2  new_confirmed_t1  new_confirmed_t2  new_confirmed_t3  \
# 0           NaN               NaN               NaN               NaN
# 1           NaN               5.0               NaN               NaN
# 2          16.0               1.0               5.0               NaN
# 3          41.0               1.0               1.0               5.0
# 4          50.0               7.0               1.0               1.0
#
#    new_confirmed_t4  new_confirmed_t5  new_confirmed_t6
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
# 3               NaN               NaN               NaN
# 4               5.0               NaN               NaN
#
# [5 rows x 25 columns]

# %%
for edge in G.edges():
    print(edge)
    city_state_0 = edge[0]
    city_state_1 = edge[1]
    temp_0 = casosGroupDf[casosGroupDf.city_state == city_state_0]
    temp_1 = casosGroupDf[casosGroupDf.city_state == city_state_1]

    for week in epi_week:
        temp2_0 = temp_0[temp_0.epidemiological_week == week]
        temp2_1 = temp_1[temp_1.epidemiological_week == week]
        if (temp2_0.empty) | (temp2_1.empty):
            new_confirmed_percent_0 = np.nan
            new_confirmed_percent_1 = np.nan
        elif temp2_0.empty:
            new_confirmed_percent_0 = 0
            new_confirmed_percent_1 = temp2_1.new_confirmed_percent.iloc[0]
        elif temp2_1.empty:
            new_confirmed_percent_1 = 0
            new_confirmed_percent_0 = temp2_0.new_confirmed_percent.iloc[0]

        else:
            new_confirmed_percent_0 = temp2_0.new_confirmed_percent.iloc[0]
            new_confirmed_percent_1 = temp2_1.new_confirmed_percent.iloc[0]

            new_confirmed_percent_avg = (
                new_confirmed_percent_0 + new_confirmed_percent_1
            ) / 2
            new_confirmed_percent_diff = (
                new_confirmed_percent_0 * new_confirmed_percent_1
            )
            new_confirmed_percent_avg_df.loc[
                week, str(edge)
            ] = new_confirmed_percent_avg
            new_confirmed_percent_diff_df.loc[
                week, str(edge)
            ] = new_confirmed_percent_diff

# %%
new_confirmed_percent_avg_df.to_csv("new_confirmed_percent_avg_df_all.csv", sep=";")
new_confirmed_percent_diff_df.to_csv("new_confirmed_percent_diff_df_all.csv", sep=";")

# %%
size = len(G.edges())

# %%
i = 0
for edge in G.edges():
    city_state_a = edge[0]
    city_state_b = edge[1]
    temp_a = casosGroupDf[casosGroupDf.city_state == city_state_a]
    temp_b = casosGroupDf[casosGroupDf.city_state == city_state_b]

    for week in epi_week:
        temp2_a = temp_a[temp_a.epidemiological_week == week]
        temp2_b = temp_b[temp_b.epidemiological_week == week]

        try:
            confirmed_a = temp2_a.new_confirmed.iloc[0]
        except:
            confirmed_a = 0
        try:
            confirmed_b = temp2_b.new_confirmed.iloc[0]
        except:
            confirmed_b = 0

        # except: confirmed_t4_b = np.nan

        avg = (confirmed_a + confirmed_b) / 2
        diff = abs(confirmed_a - confirmed_b)

        new_confirmed_avg_df[week, str(edge)] = avg
        new_confirmed_diff_df[week, str(edge)] = diff
    i = i + 1
    print(edge, size - i)
# Out:
# ('ALTA FLORESTA DOESTE (RO)', 'NOVA BRASILANDIA DOESTE (RO)') 17436
# ('ALTA FLORESTA DOESTE (RO)', 'ROLIM DE MOURA (RO)') 17435
# ('ALTA FLORESTA DOESTE (RO)', 'SANTA LUZIA DOESTE (RO)') 17434
# ('ALTA FLORESTA DOESTE (RO)', 'SAO MIGUEL DO GUAPORE (RO)') 17433
# ('ALTA FLORESTA DOESTE (RO)', 'ALTO ALEGRE DOS PARECIS (RO)') 17432
# ('ALTA FLORESTA DOESTE (RO)', 'NOVO HORIZONTE DO OESTE (RO)') 17431
# ('ALTA FLORESTA DOESTE (RO)', 'SAO FRANCISCO DO GUAPORE (RO)') 17430
# ('NOVA BRASILANDIA DOESTE (RO)', 'PRESIDENTE MEDICI (RO)') 17429
# ('NOVA BRASILANDIA DOESTE (RO)', 'SAO MIGUEL DO GUAPORE (RO)') 17428
# ('NOVA BRASILANDIA DOESTE (RO)', 'ALVORADA DOESTE (RO)') 17427
# ('NOVA BRASILANDIA DOESTE (RO)', 'NOVO HORIZONTE DO OESTE (RO)') 17426
# ('NOVA BRASILANDIA DOESTE (RO)', 'CASTANHEIRAS (RO)') 17425
# ('ROLIM DE MOURA (RO)', 'CACOAL (RO)') 17424
# ('ROLIM DE MOURA (RO)', 'PIMENTA BUENO (RO)') 17423
# ('ROLIM DE MOURA (RO)', 'SANTA LUZIA DOESTE (RO)') 17422
# ('ROLIM DE MOURA (RO)', 'NOVO HORIZONTE DO OESTE (RO)') 17421
# ('ROLIM DE MOURA (RO)', 'CASTANHEIRAS (RO)') 17420
# ('ROLIM DE MOURA (RO)', 'SAO FELIPE DOESTE (RO)') 17419
# ('SANTA LUZIA DOESTE (RO)', 'ALTO ALEGRE DOS PARECIS (RO)') 17418
# ('SANTA LUZIA DOESTE (RO)', 'PARECIS (RO)') 17417
# ('SANTA LUZIA DOESTE (RO)', 'SAO FELIPE DOESTE (RO)') 17416
# ('SAO MIGUEL DO GUAPORE (RO)', 'GUAJARAMIRIM (RO)') 17415
# ('SAO MIGUEL DO GUAPORE (RO)', 'ALVORADA DOESTE (RO)') 17414
# ('SAO MIGUEL DO GUAPORE (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17413
# ('SAO MIGUEL DO GUAPORE (RO)', 'SAO FRANCISCO DO GUAPORE (RO)') 17412
# ('SAO MIGUEL DO GUAPORE (RO)', 'SERINGUEIRAS (RO)') 17411
# ('ALTO ALEGRE DOS PARECIS (RO)', 'PARECIS (RO)') 17410
# ('ALTO ALEGRE DOS PARECIS (RO)', 'PIMENTEIRAS DO OESTE (RO)') 17409
# ('NOVO HORIZONTE DO OESTE (RO)', 'CASTANHEIRAS (RO)') 17408
# ('SAO FRANCISCO DO GUAPORE (RO)', 'COSTA MARQUES (RO)') 17407
# ('SAO FRANCISCO DO GUAPORE (RO)', 'SERINGUEIRAS (RO)') 17406
# ('ARIQUEMES (RO)', 'JARU (RO)') 17405
# ('ARIQUEMES (RO)', 'MACHADINHO DOESTE (RO)') 17404
# ('ARIQUEMES (RO)', 'RIO CRESPO (RO)') 17403
# ('ARIQUEMES (RO)', 'ALTO PARAISO (RO)') 17402
# ('ARIQUEMES (RO)', 'BURITIS (RO)') 17401
# ('ARIQUEMES (RO)', 'CACAULANDIA (RO)') 17400
# ('ARIQUEMES (RO)', 'MONTE NEGRO (RO)') 17399
# ('ARIQUEMES (RO)', 'THEOBROMA (RO)') 17398
# ('ARIQUEMES (RO)', 'VALE DO ANARI (RO)') 17397
# ('JARU (RO)', 'OURO PRETO DO OESTE (RO)') 17396
# ('JARU (RO)', 'CACAULANDIA (RO)') 17395
# ('JARU (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17394
# ('JARU (RO)', 'MIRANTE DA SERRA (RO)') 17393
# ('JARU (RO)', 'NOVA UNIAO (RO)') 17392
# ('JARU (RO)', 'THEOBROMA (RO)') 17391
# ('JARU (RO)', 'VALE DO PARAISO (RO)') 17390
# ('MACHADINHO DOESTE (RO)', 'PORTO VELHO (RO)') 17389
# ('MACHADINHO DOESTE (RO)', 'RIO CRESPO (RO)') 17388
# ('MACHADINHO DOESTE (RO)', 'CUJUBIM (RO)') 17387
# ('MACHADINHO DOESTE (RO)', 'VALE DO ANARI (RO)') 17386
# ('MACHADINHO DOESTE (RO)', 'HUMAITA (AM)') 17385
# ('MACHADINHO DOESTE (RO)', 'MANICORE (AM)') 17384
# ('MACHADINHO DOESTE (RO)', 'NOVO ARIPUANA (AM)') 17383
# ('MACHADINHO DOESTE (RO)', 'COLNIZA (MT)') 17382
# ('RIO CRESPO (RO)', 'ALTO PARAISO (RO)') 17381
# ('RIO CRESPO (RO)', 'CUJUBIM (RO)') 17380
# ('ALTO PARAISO (RO)', 'PORTO VELHO (RO)') 17379
# ('ALTO PARAISO (RO)', 'BURITIS (RO)') 17378
# ('ALTO PARAISO (RO)', 'CANDEIAS DO JAMARI (RO)') 17377
# ('ALTO PARAISO (RO)', 'CUJUBIM (RO)') 17376
# ('ALTO PARAISO (RO)', 'ITAPUA DO OESTE (RO)') 17375
# ('ALTO PARAISO (RO)', 'MONTE NEGRO (RO)') 17374
# ('BURITIS (RO)', 'PORTO VELHO (RO)') 17373
# ('BURITIS (RO)', 'NOVA MAMORE (RO)') 17372
# ('BURITIS (RO)', 'CAMPO NOVO DE RONDONIA (RO)') 17371
# ('BURITIS (RO)', 'MONTE NEGRO (RO)') 17370
# ('CACAULANDIA (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17369
# ('CACAULANDIA (RO)', 'MONTE NEGRO (RO)') 17368
# ('MONTE NEGRO (RO)', 'CAMPO NOVO DE RONDONIA (RO)') 17367
# ('MONTE NEGRO (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17366
# ('THEOBROMA (RO)', 'JIPARANA (RO)') 17365
# ('THEOBROMA (RO)', 'VALE DO ANARI (RO)') 17364
# ('THEOBROMA (RO)', 'VALE DO PARAISO (RO)') 17363
# ('VALE DO ANARI (RO)', 'JIPARANA (RO)') 17362
# ('VALE DO ANARI (RO)', 'COLNIZA (MT)') 17361
# ('CABIXI (RO)', 'COLORADO DO OESTE (RO)') 17360
# ('CABIXI (RO)', 'PIMENTEIRAS DO OESTE (RO)') 17359
# ('CABIXI (RO)', 'COMODORO (MT)') 17358
# ('COLORADO DO OESTE (RO)', 'CEREJEIRAS (RO)') 17357
# ('COLORADO DO OESTE (RO)', 'CORUMBIARA (RO)') 17356
# ('COLORADO DO OESTE (RO)', 'VILHENA (RO)') 17355
# ('COLORADO DO OESTE (RO)', 'CHUPINGUAIA (RO)') 17354
# ('COLORADO DO OESTE (RO)', 'PIMENTEIRAS DO OESTE (RO)') 17353
# ('COLORADO DO OESTE (RO)', 'COMODORO (MT)') 17352
# ('PIMENTEIRAS DO OESTE (RO)', 'CEREJEIRAS (RO)') 17351
# ('PIMENTEIRAS DO OESTE (RO)', 'CORUMBIARA (RO)') 17350
# ('PIMENTEIRAS DO OESTE (RO)', 'CHUPINGUAIA (RO)') 17349
# ('PIMENTEIRAS DO OESTE (RO)', 'PARECIS (RO)') 17348
# ('COMODORO (MT)', 'VILHENA (RO)') 17347
# ('COMODORO (MT)', 'CAMPOS DE JULIO (MT)') 17346
# ('COMODORO (MT)', 'JUINA (MT)') 17345
# ('COMODORO (MT)', 'VILA BELA DA SANTISSIMA TRINDADE (MT)') 17344
# ('COMODORO (MT)', 'NOVA LACERDA (MT)') 17343
# ('COMODORO (MT)', 'SAPEZAL (MT)') 17342
# ('CACOAL (RO)', 'ESPIGAO DOESTE (RO)') 17341
# ('CACOAL (RO)', 'PIMENTA BUENO (RO)') 17340
# ('CACOAL (RO)', 'PRESIDENTE MEDICI (RO)') 17339
# ('CACOAL (RO)', 'CASTANHEIRAS (RO)') 17338
# ('CACOAL (RO)', 'MINISTRO ANDREAZZA (RO)') 17337
# ('CACOAL (RO)', 'RONDOLANDIA (MT)') 17336
# ('CACOAL (RO)', 'VARZEA GRANDE (MT)') 17335
# ('CACOAL (RO)', 'CAMPINAS (SP)') 17334
# ('CACOAL (RO)', 'JIPARANA (RO)') 17333
# ('ESPIGAO DOESTE (RO)', 'PIMENTA BUENO (RO)') 17332
# ('ESPIGAO DOESTE (RO)', 'VILHENA (RO)') 17331
# ('ESPIGAO DOESTE (RO)', 'JUINA (MT)') 17330
# ('ESPIGAO DOESTE (RO)', 'RONDOLANDIA (MT)') 17329
# ('PIMENTA BUENO (RO)', 'VILHENA (RO)') 17328
# ('PIMENTA BUENO (RO)', 'CHUPINGUAIA (RO)') 17327
# ('PIMENTA BUENO (RO)', 'PARECIS (RO)') 17326
# ('PIMENTA BUENO (RO)', 'PRIMAVERA DE RONDONIA (RO)') 17325
# ('PIMENTA BUENO (RO)', 'SAO FELIPE DOESTE (RO)') 17324
# ('PRESIDENTE MEDICI (RO)', 'JIPARANA (RO)') 17323
# ('PRESIDENTE MEDICI (RO)', 'ALVORADA DOESTE (RO)') 17322
# ('PRESIDENTE MEDICI (RO)', 'CASTANHEIRAS (RO)') 17321
# ('PRESIDENTE MEDICI (RO)', 'MINISTRO ANDREAZZA (RO)') 17320
# ('PRESIDENTE MEDICI (RO)', 'URUPA (RO)') 17319
# ('MINISTRO ANDREAZZA (RO)', 'JIPARANA (RO)') 17318
# ('MINISTRO ANDREAZZA (RO)', 'RONDOLANDIA (MT)') 17317
# ('RONDOLANDIA (MT)', 'JIPARANA (RO)') 17316
# ('RONDOLANDIA (MT)', 'VILHENA (RO)') 17315
# ('RONDOLANDIA (MT)', 'ARIPUANA (MT)') 17314
# ('RONDOLANDIA (MT)', 'COLNIZA (MT)') 17313
# ('RONDOLANDIA (MT)', 'JUINA (MT)') 17312
# ('CEREJEIRAS (RO)', 'CORUMBIARA (RO)') 17311
# ('CORUMBIARA (RO)', 'CHUPINGUAIA (RO)') 17310
# ('VILHENA (RO)', 'CHUPINGUAIA (RO)') 17309
# ('VILHENA (RO)', 'JUINA (MT)') 17308
# ('VILHENA (RO)', 'JIPARANA (RO)') 17307
# ('VILHENA (RO)', 'VARZEA GRANDE (MT)') 17306
# ('VILHENA (RO)', 'CAMPINAS (SP)') 17305
# ('CHUPINGUAIA (RO)', 'PARECIS (RO)') 17304
# ('COSTA MARQUES (RO)', 'GUAJARAMIRIM (RO)') 17303
# ('COSTA MARQUES (RO)', 'SERINGUEIRAS (RO)') 17302
# ('GUAJARAMIRIM (RO)', 'NOVA MAMORE (RO)') 17301
# ('GUAJARAMIRIM (RO)', 'CAMPO NOVO DE RONDONIA (RO)') 17300
# ('GUAJARAMIRIM (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17299
# ('GUAJARAMIRIM (RO)', 'SERINGUEIRAS (RO)') 17298
# ('JUINA (MT)', 'ARIPUANA (MT)') 17297
# ('JUINA (MT)', 'BRASNORTE (MT)') 17296
# ('JUINA (MT)', 'CASTANHEIRA (MT)') 17295
# ('JUINA (MT)', 'JURUENA (MT)') 17294
# ('JUINA (MT)', 'SAPEZAL (MT)') 17293
# ('JUINA (MT)', 'JUARA (MT)') 17292
# ('JUINA (MT)', 'VARZEA GRANDE (MT)') 17291
# ('JUINA (MT)', 'TANGARA DA SERRA (MT)') 17290
# ('JUINA (MT)', 'PONTES E LACERDA (MT)') 17289
# ('JUINA (MT)', 'NOVA MUTUM (MT)') 17288
# ('JUINA (MT)', 'LUCAS DO RIO VERDE (MT)') 17287
# ('NOVA MAMORE (RO)', 'PORTO VELHO (RO)') 17286
# ('NOVA MAMORE (RO)', 'CAMPO NOVO DE RONDONIA (RO)') 17285
# ('CAMPO NOVO DE RONDONIA (RO)', 'GOVERNADOR JORGE TEIXEIRA (RO)') 17284
# ('GOVERNADOR JORGE TEIXEIRA (RO)', 'ALVORADA DOESTE (RO)') 17283
# ('GOVERNADOR JORGE TEIXEIRA (RO)', 'MIRANTE DA SERRA (RO)') 17282
# ('OURO PRETO DO OESTE (RO)', 'JIPARANA (RO)') 17281
# ('OURO PRETO DO OESTE (RO)', 'NOVA UNIAO (RO)') 17280
# ('OURO PRETO DO OESTE (RO)', 'TEIXEIROPOLIS (RO)') 17279
# ('OURO PRETO DO OESTE (RO)', 'VALE DO PARAISO (RO)') 17278
# ('MIRANTE DA SERRA (RO)', 'ALVORADA DOESTE (RO)') 17277
# ('MIRANTE DA SERRA (RO)', 'NOVA UNIAO (RO)') 17276
# ('MIRANTE DA SERRA (RO)', 'URUPA (RO)') 17275
# ('NOVA UNIAO (RO)', 'TEIXEIROPOLIS (RO)') 17274
# ('NOVA UNIAO (RO)', 'URUPA (RO)') 17273
# ('VALE DO PARAISO (RO)', 'JIPARANA (RO)') 17272
# ('JIPARANA (RO)', 'TEIXEIROPOLIS (RO)') 17271
# ('JIPARANA (RO)', 'URUPA (RO)') 17270
# ('JIPARANA (RO)', 'COLNIZA (MT)') 17269
# ('JIPARANA (RO)', 'CONFINS (MG)') 17268
# ('JIPARANA (RO)', 'VARZEA GRANDE (MT)') 17267
# ('JIPARANA (RO)', 'CAMPINAS (SP)') 17266
# ('TEIXEIROPOLIS (RO)', 'URUPA (RO)') 17265
# ('URUPA (RO)', 'ALVORADA DOESTE (RO)') 17264
# ('COLNIZA (MT)', 'APUI (AM)') 17263
# ('COLNIZA (MT)', 'NOVO ARIPUANA (AM)') 17262
# ('COLNIZA (MT)', 'ARIPUANA (MT)') 17261
# ('COLNIZA (MT)', 'COTRIGUACU (MT)') 17260
# ('PORTO VELHO (RO)', 'CANDEIAS DO JAMARI (RO)') 17259
# ('PORTO VELHO (RO)', 'CUJUBIM (RO)') 17258
# ('PORTO VELHO (RO)', 'ITAPUA DO OESTE (RO)') 17257
# ('PORTO VELHO (RO)', 'ACRELANDIA (AC)') 17256
# ('PORTO VELHO (RO)', 'CANUTAMA (AM)') 17255
# ('PORTO VELHO (RO)', 'HUMAITA (AM)') 17254
# ('PORTO VELHO (RO)', 'LABREA (AM)') 17253
# ('PORTO VELHO (RO)', 'BELEM (PA)') 17252
# ('PORTO VELHO (RO)', 'BRASILIA (DF)') 17251
# ('PORTO VELHO (RO)', 'CAMPINAS (SP)') 17250
# ('PORTO VELHO (RO)', 'CONFINS (MG)') 17249
# ('PORTO VELHO (RO)', 'FORTALEZA (CE)') 17248
# ('PORTO VELHO (RO)', 'GUARULHOS (SP)') 17247
# ('PORTO VELHO (RO)', 'MANAUS (AM)') 17246
# ('PORTO VELHO (RO)', 'VARZEA GRANDE (MT)') 17245
# ('PORTO VELHO (RO)', 'BOA VISTA (RR)') 17244
# ('PORTO VELHO (RO)', 'SAO PAULO (SP)') 17243
# ('PORTO VELHO (RO)', 'RECIFE (PE)') 17242
# ('PORTO VELHO (RO)', 'RIO BRANCO (AC)') 17241
# ('PORTO VELHO (RO)', 'RIO DE JANEIRO (RJ)') 17240
# ('PORTO VELHO (RO)', 'TEFE (AM)') 17239
# ('PORTO VELHO (RO)', 'COARI (AM)') 17238
# ('PORTO VELHO (RO)', 'SAO CARLOS (SP)') 17237
# ('PORTO VELHO (RO)', 'RIBEIRAO PRETO (SP)') 17236
# ('PORTO VELHO (RO)', 'UBERLANDIA (MG)') 17235
# ('PORTO VELHO (RO)', 'GOIANIA (GO)') 17234
# ('PORTO VELHO (RO)', 'SANTAREM (PA)') 17233
# ('CUJUBIM (RO)', 'CANDEIAS DO JAMARI (RO)') 17232
# ('CUJUBIM (RO)', 'ITAPUA DO OESTE (RO)') 17231
# ('HUMAITA (AM)', 'CANUTAMA (AM)') 17230
# ('HUMAITA (AM)', 'MANICORE (AM)') 17229
# ('HUMAITA (AM)', 'TAPAUA (AM)') 17228
# ('MANICORE (AM)', 'BERURI (AM)') 17227
# ('MANICORE (AM)', 'BORBA (AM)') 17226
# ('MANICORE (AM)', 'NOVO ARIPUANA (AM)') 17225
# ('MANICORE (AM)', 'TAPAUA (AM)') 17224
# ('NOVO ARIPUANA (AM)', 'APUI (AM)') 17223
# ('NOVO ARIPUANA (AM)', 'BORBA (AM)') 17222
# ('PARECIS (RO)', 'PRIMAVERA DE RONDONIA (RO)') 17221
# ('PARECIS (RO)', 'SAO FELIPE DOESTE (RO)') 17220
# ('PRIMAVERA DE RONDONIA (RO)', 'SAO FELIPE DOESTE (RO)') 17219
# ('CANDEIAS DO JAMARI (RO)', 'ITAPUA DO OESTE (RO)') 17218
# ('ACRELANDIA (AC)', 'PLACIDO DE CASTRO (AC)') 17217
# ('ACRELANDIA (AC)', 'SENADOR GUIOMARD (AC)') 17216
# ('ACRELANDIA (AC)', 'LABREA (AM)') 17215
# ('CANUTAMA (AM)', 'LABREA (AM)') 17214
# ('CANUTAMA (AM)', 'TAPAUA (AM)') 17213
# ('LABREA (AM)', 'SENADOR GUIOMARD (AC)') 17212
# ('LABREA (AM)', 'PORTO ACRE (AC)') 17211
# ('LABREA (AM)', 'BOCA DO ACRE (AM)') 17210
# ('LABREA (AM)', 'ITAMARATI (AM)') 17209
# ('LABREA (AM)', 'PAUINI (AM)') 17208
# ('LABREA (AM)', 'TAPAUA (AM)') 17207
# ('LABREA (AM)', 'COARI (AM)') 17206
# ('LABREA (AM)', 'MANAUS (AM)') 17205
# ('LABREA (AM)', 'TEFE (AM)') 17204
# ('PLACIDO DE CASTRO (AC)', 'CAPIXABA (AC)') 17203
# ('PLACIDO DE CASTRO (AC)', 'SENADOR GUIOMARD (AC)') 17202
# ('SENADOR GUIOMARD (AC)', 'CAPIXABA (AC)') 17201
# ('SENADOR GUIOMARD (AC)', 'RIO BRANCO (AC)') 17200
# ('SENADOR GUIOMARD (AC)', 'PORTO ACRE (AC)') 17199
# ('ASSIS BRASIL (AC)', 'BRASILEIA (AC)') 17198
# ('ASSIS BRASIL (AC)', 'SENA MADUREIRA (AC)') 17197
# ('BRASILEIA (AC)', 'EPITACIOLANDIA (AC)') 17196
# ('BRASILEIA (AC)', 'RIO BRANCO (AC)') 17195
# ('BRASILEIA (AC)', 'SENA MADUREIRA (AC)') 17194
# ('BRASILEIA (AC)', 'XAPURI (AC)') 17193
# ('SENA MADUREIRA (AC)', 'BUJARI (AC)') 17192
# ('SENA MADUREIRA (AC)', 'MANOEL URBANO (AC)') 17191
# ('SENA MADUREIRA (AC)', 'RIO BRANCO (AC)') 17190
# ('SENA MADUREIRA (AC)', 'BOCA DO ACRE (AM)') 17189
# ('EPITACIOLANDIA (AC)', 'XAPURI (AC)') 17188
# ('RIO BRANCO (AC)', 'BUJARI (AC)') 17187
# ('RIO BRANCO (AC)', 'CAPIXABA (AC)') 17186
# ('RIO BRANCO (AC)', 'XAPURI (AC)') 17185
# ('RIO BRANCO (AC)', 'PORTO ACRE (AC)') 17184
# ('RIO BRANCO (AC)', 'BRASILIA (DF)') 17183
# ('RIO BRANCO (AC)', 'CAMPINAS (SP)') 17182
# ('RIO BRANCO (AC)', 'CRUZEIRO DO SUL (AC)') 17181
# ('RIO BRANCO (AC)', 'GUARULHOS (SP)') 17180
# ('RIO BRANCO (AC)', 'MANAUS (AM)') 17179
# ('RIO BRANCO (AC)', 'VARZEA GRANDE (MT)') 17178
# ('RIO BRANCO (AC)', 'CONFINS (MG)') 17177
# ('RIO BRANCO (AC)', 'SAO CARLOS (SP)') 17176
# ('RIO BRANCO (AC)', 'GOIANIA (GO)') 17175
# ('XAPURI (AC)', 'CAPIXABA (AC)') 17174
# ('BUJARI (AC)', 'PORTO ACRE (AC)') 17173
# ('BUJARI (AC)', 'BOCA DO ACRE (AM)') 17172
# ('PORTO ACRE (AC)', 'BOCA DO ACRE (AM)') 17171
# ('BOCA DO ACRE (AM)', 'MANOEL URBANO (AC)') 17170
# ('BOCA DO ACRE (AM)', 'PAUINI (AM)') 17169
# ('CRUZEIRO DO SUL (AC)', 'MANCIO LIMA (AC)') 17168
# ('CRUZEIRO DO SUL (AC)', 'PORTO WALTER (AC)') 17167
# ('CRUZEIRO DO SUL (AC)', 'RODRIGUES ALVES (AC)') 17166
# ('CRUZEIRO DO SUL (AC)', 'TARAUACA (AC)') 17165
# ('CRUZEIRO DO SUL (AC)', 'GUAJARA (AM)') 17164
# ('CRUZEIRO DO SUL (AC)', 'IPIXUNA (AM)') 17163
# ('CRUZEIRO DO SUL (AC)', 'BRASILIA (DF)') 17162
# ('CRUZEIRO DO SUL (AC)', 'CONFINS (MG)') 17161
# ('CRUZEIRO DO SUL (AC)', 'VARZEA GRANDE (MT)') 17160
# ('MANCIO LIMA (AC)', 'RODRIGUES ALVES (AC)') 17159
# ('MANCIO LIMA (AC)', 'ATALAIA DO NORTE (AM)') 17158
# ('MANCIO LIMA (AC)', 'GUAJARA (AM)') 17157
# ('PORTO WALTER (AC)', 'MARECHAL THAUMATURGO (AC)') 17156
# ('PORTO WALTER (AC)', 'TARAUACA (AC)') 17155
# ('TARAUACA (AC)', 'FEIJO (AC)') 17154
# ('TARAUACA (AC)', 'JORDAO (AC)') 17153
# ('TARAUACA (AC)', 'MARECHAL THAUMATURGO (AC)') 17152
# ('TARAUACA (AC)', 'EIRUNEPE (AM)') 17151
# ('TARAUACA (AC)', 'ENVIRA (AM)') 17150
# ('TARAUACA (AC)', 'IPIXUNA (AM)') 17149
# ('GUAJARA (AM)', 'ATALAIA DO NORTE (AM)') 17148
# ('GUAJARA (AM)', 'IPIXUNA (AM)') 17147
# ('IPIXUNA (AM)', 'ATALAIA DO NORTE (AM)') 17146
# ('IPIXUNA (AM)', 'BENJAMIN CONSTANT (AM)') 17145
# ('IPIXUNA (AM)', 'EIRUNEPE (AM)') 17144
# ('FEIJO (AC)', 'JORDAO (AC)') 17143
# ('FEIJO (AC)', 'MANOEL URBANO (AC)') 17142
# ('FEIJO (AC)', 'SANTA ROSA DO PURUS (AC)') 17141
# ('FEIJO (AC)', 'ENVIRA (AM)') 17140
# ('FEIJO (AC)', 'PAUINI (AM)') 17139
# ('JORDAO (AC)', 'MARECHAL THAUMATURGO (AC)') 17138
# ('MANOEL URBANO (AC)', 'SANTA ROSA DO PURUS (AC)') 17137
# ('MANOEL URBANO (AC)', 'PAUINI (AM)') 17136
# ('ENVIRA (AM)', 'EIRUNEPE (AM)') 17135
# ('ENVIRA (AM)', 'ITAMARATI (AM)') 17134
# ('ENVIRA (AM)', 'PAUINI (AM)') 17133
# ('PAUINI (AM)', 'ITAMARATI (AM)') 17132
# ('ATALAIA DO NORTE (AM)', 'BENJAMIN CONSTANT (AM)') 17131
# ('EIRUNEPE (AM)', 'BENJAMIN CONSTANT (AM)') 17130
# ('EIRUNEPE (AM)', 'ITAMARATI (AM)') 17129
# ('EIRUNEPE (AM)', 'JUTAI (AM)') 17128
# ('EIRUNEPE (AM)', 'MANAUS (AM)') 17127
# ('EIRUNEPE (AM)', 'TEFE (AM)') 17126
# ('EIRUNEPE (AM)', 'CARAUARI (AM)') 17125
# ('EIRUNEPE (AM)', 'TABATINGA (AM)') 17124
# ('EIRUNEPE (AM)', 'SAO GABRIEL DA CACHOEIRA (AM)') 17123
# ('ALVARAES (AM)', 'JURUA (AM)') 17122
# ('ALVARAES (AM)', 'MARAA (AM)') 17121
# ('ALVARAES (AM)', 'TEFE (AM)') 17120
# ('ALVARAES (AM)', 'UARINI (AM)') 17119
# ('JURUA (AM)', 'CARAUARI (AM)') 17118
# ('JURUA (AM)', 'FONTE BOA (AM)') 17117
# ('JURUA (AM)', 'JUTAI (AM)') 17116
# ('JURUA (AM)', 'TEFE (AM)') 17115
# ('JURUA (AM)', 'UARINI (AM)') 17114
# ('MARAA (AM)', 'BARCELOS (AM)') 17113
# ('MARAA (AM)', 'COARI (AM)') 17112
# ('MARAA (AM)', 'CODAJAS (AM)') 17111
# ('MARAA (AM)', 'FONTE BOA (AM)') 17110
# ('MARAA (AM)', 'JAPURA (AM)') 17109
# ('MARAA (AM)', 'SANTA ISABEL DO RIO NEGRO (AM)') 17108
# ('MARAA (AM)', 'TEFE (AM)') 17107
# ('MARAA (AM)', 'UARINI (AM)') 17106
# ('TEFE (AM)', 'CARAUARI (AM)') 17105
# ('TEFE (AM)', 'COARI (AM)') 17104
# ('TEFE (AM)', 'TAPAUA (AM)') 17103
# ('TEFE (AM)', 'MANAUS (AM)') 17102
# ('TEFE (AM)', 'SAO GABRIEL DA CACHOEIRA (AM)') 17101
# ('TEFE (AM)', 'TABATINGA (AM)') 17100
# ('TEFE (AM)', 'BOA VISTA (RR)') 17099
# ('UARINI (AM)', 'FONTE BOA (AM)') 17098
# ('AMATURA (AM)', 'JUTAI (AM)') 17097
# ('AMATURA (AM)', 'SANTO ANTONIO DO ICA (AM)') 17096
# ('AMATURA (AM)', 'SAO PAULO DE OLIVENCA (AM)') 17095
# ('JUTAI (AM)', 'BENJAMIN CONSTANT (AM)') 17094
# ('JUTAI (AM)', 'CARAUARI (AM)') 17093
# ('JUTAI (AM)', 'FONTE BOA (AM)') 17092
# ('JUTAI (AM)', 'ITAMARATI (AM)') 17091
# ('JUTAI (AM)', 'SANTO ANTONIO DO ICA (AM)') 17090
# ('JUTAI (AM)', 'SAO PAULO DE OLIVENCA (AM)') 17089
# ('JUTAI (AM)', 'TONANTINS (AM)') 17088
# ('SANTO ANTONIO DO ICA (AM)', 'JAPURA (AM)') 17087
# ('SANTO ANTONIO DO ICA (AM)', 'SAO PAULO DE OLIVENCA (AM)') 17086
# ('SANTO ANTONIO DO ICA (AM)', 'TABATINGA (AM)') 17085
# ('SANTO ANTONIO DO ICA (AM)', 'TONANTINS (AM)') 17084
# ('SAO PAULO DE OLIVENCA (AM)', 'BENJAMIN CONSTANT (AM)') 17083
# ('SAO PAULO DE OLIVENCA (AM)', 'TABATINGA (AM)') 17082
# ('ANAMA (AM)', 'ANORI (AM)') 17081
# ('ANAMA (AM)', 'BERURI (AM)') 17080
# ('ANAMA (AM)', 'CAAPIRANGA (AM)') 17079
# ('ANAMA (AM)', 'CODAJAS (AM)') 17078
# ('ANAMA (AM)', 'MANACAPURU (AM)') 17077
# ('ANORI (AM)', 'BERURI (AM)') 17076
# ('ANORI (AM)', 'COARI (AM)') 17075
# ('ANORI (AM)', 'CODAJAS (AM)') 17074
# ('ANORI (AM)', 'TAPAUA (AM)') 17073
# ('BERURI (AM)', 'BORBA (AM)') 17072
# ('BERURI (AM)', 'CAREIRO (AM)') 17071
# ('BERURI (AM)', 'MANACAPURU (AM)') 17070
# ('BERURI (AM)', 'MANAQUIRI (AM)') 17069
# ('BERURI (AM)', 'TAPAUA (AM)') 17068
# ('CAAPIRANGA (AM)', 'CODAJAS (AM)') 17067
# ('CAAPIRANGA (AM)', 'MANACAPURU (AM)') 17066
# ('CAAPIRANGA (AM)', 'NOVO AIRAO (AM)') 17065
# ('CODAJAS (AM)', 'BARCELOS (AM)') 17064
# ('CODAJAS (AM)', 'COARI (AM)') 17063
# ('CODAJAS (AM)', 'NOVO AIRAO (AM)') 17062
# ('MANACAPURU (AM)', 'IRANDUBA (AM)') 17061
# ('MANACAPURU (AM)', 'MANAQUIRI (AM)') 17060
# ('MANACAPURU (AM)', 'NOVO AIRAO (AM)') 17059
# ('COARI (AM)', 'BARCELOS (AM)') 17058
# ('COARI (AM)', 'TAPAUA (AM)') 17057
# ('COARI (AM)', 'CARAUARI (AM)') 17056
# ('COARI (AM)', 'MANAUS (AM)') 17055
# ('TAPAUA (AM)', 'CARAUARI (AM)') 17054
# ('TAPAUA (AM)', 'ITAMARATI (AM)') 17053
# ('APUI (AM)', 'BORBA (AM)') 17052
# ('APUI (AM)', 'MAUES (AM)') 17051
# ('APUI (AM)', 'JACAREACANGA (PA)') 17050
# ('APUI (AM)', 'APIACAS (MT)') 17049
# ('APUI (AM)', 'COTRIGUACU (MT)') 17048
# ('BORBA (AM)', 'AUTAZES (AM)') 17047
# ('BORBA (AM)', 'CAREIRO (AM)') 17046
# ('BORBA (AM)', 'MANAQUIRI (AM)') 17045
# ('BORBA (AM)', 'MAUES (AM)') 17044
# ('BORBA (AM)', 'NOVA OLINDA DO NORTE (AM)') 17043
# ('MAUES (AM)', 'BARREIRINHA (AM)') 17042
# ('MAUES (AM)', 'BOA VISTA DO RAMOS (AM)') 17041
# ('MAUES (AM)', 'ITACOATIARA (AM)') 17040
# ('MAUES (AM)', 'NOVA OLINDA DO NORTE (AM)') 17039
# ('MAUES (AM)', 'AVEIRO (PA)') 17038
# ('MAUES (AM)', 'ITAITUBA (PA)') 17037
# ('MAUES (AM)', 'JACAREACANGA (PA)') 17036
# ('MAUES (AM)', 'MANAUS (AM)') 17035
# ('MAUES (AM)', 'PARINTINS (AM)') 17034
# ('JACAREACANGA (PA)', 'ITAITUBA (PA)') 17033
# ('JACAREACANGA (PA)', 'NOVO PROGRESSO (PA)') 17032
# ('JACAREACANGA (PA)', 'ALTA FLORESTA (MT)') 17031
# ('JACAREACANGA (PA)', 'APIACAS (MT)') 17030
# ('JACAREACANGA (PA)', 'PARANAITA (MT)') 17029
# ('APIACAS (MT)', 'COTRIGUACU (MT)') 17028
# ('APIACAS (MT)', 'NOVA BANDEIRANTES (MT)') 17027
# ('APIACAS (MT)', 'PARANAITA (MT)') 17026
# ('APIACAS (MT)', 'NOVA MONTE VERDE (MT)') 17025
# ('COTRIGUACU (MT)', 'ARIPUANA (MT)') 17024
# ('COTRIGUACU (MT)', 'JURUENA (MT)') 17023
# ('COTRIGUACU (MT)', 'NOVA BANDEIRANTES (MT)') 17022
# ('BENJAMIN CONSTANT (AM)', 'TABATINGA (AM)') 17021
# ('AUTAZES (AM)', 'CAREIRO (AM)') 17020
# ('AUTAZES (AM)', 'CAREIRO DA VARZEA (AM)') 17019
# ('AUTAZES (AM)', 'ITACOATIARA (AM)') 17018
# ('AUTAZES (AM)', 'NOVA OLINDA DO NORTE (AM)') 17017
# ('CAREIRO (AM)', 'CAREIRO DA VARZEA (AM)') 17016
# ('CAREIRO (AM)', 'MANAQUIRI (AM)') 17015
# ('CAREIRO DA VARZEA (AM)', 'IRANDUBA (AM)') 17014
# ('CAREIRO DA VARZEA (AM)', 'ITACOATIARA (AM)') 17013
# ('CAREIRO DA VARZEA (AM)', 'MANAQUIRI (AM)') 17012
# ('CAREIRO DA VARZEA (AM)', 'MANAUS (AM)') 17011
# ('ITACOATIARA (AM)', 'BOA VISTA DO RAMOS (AM)') 17010
# ('ITACOATIARA (AM)', 'ITAPIRANGA (AM)') 17009
# ('ITACOATIARA (AM)', 'MANAUS (AM)') 17008
# ('ITACOATIARA (AM)', 'NOVA OLINDA DO NORTE (AM)') 17007
# ('ITACOATIARA (AM)', 'RIO PRETO DA EVA (AM)') 17006
# ('ITACOATIARA (AM)', 'SILVES (AM)') 17005
# ('ITACOATIARA (AM)', 'URUCURITUBA (AM)') 17004
# ('BARCELOS (AM)', 'NOVO AIRAO (AM)') 17003
# ('BARCELOS (AM)', 'SANTA ISABEL DO RIO NEGRO (AM)') 17002
# ('BARCELOS (AM)', 'CARACARAI (RR)') 17001
# ('BARCELOS (AM)', 'IRACEMA (RR)') 17000
# ('BARCELOS (AM)', 'RORAINOPOLIS (RR)') 16999
# ('NOVO AIRAO (AM)', 'IRANDUBA (AM)') 16998
# ('NOVO AIRAO (AM)', 'MANAUS (AM)') 16997
# ('NOVO AIRAO (AM)', 'PRESIDENTE FIGUEIREDO (AM)') 16996
# ('NOVO AIRAO (AM)', 'RORAINOPOLIS (RR)') 16995
# ('SANTA ISABEL DO RIO NEGRO (AM)', 'JAPURA (AM)') 16994
# ('SANTA ISABEL DO RIO NEGRO (AM)', 'SAO GABRIEL DA CACHOEIRA (AM)') 16993
# ('CARACARAI (RR)', 'BONFIM (RR)') 16992
# ('CARACARAI (RR)', 'CANTA (RR)') 16991
# ('CARACARAI (RR)', 'CAROEBE (RR)') 16990
# ('CARACARAI (RR)', 'IRACEMA (RR)') 16989
# ('CARACARAI (RR)', 'RORAINOPOLIS (RR)') 16988
# ('CARACARAI (RR)', 'SAO JOAO DA BALIZA (RR)') 16987
# ('CARACARAI (RR)', 'SAO LUIZ (RR)') 16986
# ('IRACEMA (RR)', 'ALTO ALEGRE (RR)') 16985
# ('IRACEMA (RR)', 'CANTA (RR)') 16984
# ('IRACEMA (RR)', 'MUCAJAI (RR)') 16983
# ('RORAINOPOLIS (RR)', 'PRESIDENTE FIGUEIREDO (AM)') 16982
# ('RORAINOPOLIS (RR)', 'URUCARA (AM)') 16981
# ('RORAINOPOLIS (RR)', 'SAO JOAO DA BALIZA (RR)') 16980
# ('RORAINOPOLIS (RR)', 'SAO LUIZ (RR)') 16979
# ('BARREIRINHA (AM)', 'BOA VISTA DO RAMOS (AM)') 16978
# ('BARREIRINHA (AM)', 'PARINTINS (AM)') 16977
# ('BARREIRINHA (AM)', 'URUCURITUBA (AM)') 16976
# ('BARREIRINHA (AM)', 'AVEIRO (PA)') 16975
# ('BOA VISTA DO RAMOS (AM)', 'URUCURITUBA (AM)') 16974
# ('PARINTINS (AM)', 'NHAMUNDA (AM)') 16973
# ('PARINTINS (AM)', 'URUCARA (AM)') 16972
# ('PARINTINS (AM)', 'URUCURITUBA (AM)') 16971
# ('PARINTINS (AM)', 'AVEIRO (PA)') 16970
# ('PARINTINS (AM)', 'JURUTI (PA)') 16969
# ('PARINTINS (AM)', 'ALTAMIRA (PA)') 16968
# ('PARINTINS (AM)', 'BELEM (PA)') 16967
# ('PARINTINS (AM)', 'ITAITUBA (PA)') 16966
# ('PARINTINS (AM)', 'MANAUS (AM)') 16965
# ('PARINTINS (AM)', 'SANTAREM (PA)') 16964
# ('PARINTINS (AM)', 'MACAPA (AP)') 16963
# ('URUCURITUBA (AM)', 'ITAPIRANGA (AM)') 16962
# ('URUCURITUBA (AM)', 'SILVES (AM)') 16961
# ('URUCURITUBA (AM)', 'URUCARA (AM)') 16960
# ('AVEIRO (PA)', 'BELTERRA (PA)') 16959
# ('AVEIRO (PA)', 'ITAITUBA (PA)') 16958
# ('AVEIRO (PA)', 'JURUTI (PA)') 16957
# ('AVEIRO (PA)', 'RUROPOLIS (PA)') 16956
# ('AVEIRO (PA)', 'SANTAREM (PA)') 16955
# ('TABATINGA (AM)', 'MANAUS (AM)') 16954
# ('TABATINGA (AM)', 'CONFINS (MG)') 16953
# ('MANAQUIRI (AM)', 'IRANDUBA (AM)') 16952
# ('CARAUARI (AM)', 'ITAMARATI (AM)') 16951
# ('CARAUARI (AM)', 'MANAUS (AM)') 16950
# ('CARAUARI (AM)', 'VARZEA GRANDE (MT)') 16949
# ('IRANDUBA (AM)', 'MANAUS (AM)') 16948
# ('MANAUS (AM)', 'PRESIDENTE FIGUEIREDO (AM)') 16947
# ('MANAUS (AM)', 'RIO PRETO DA EVA (AM)') 16946
# ('MANAUS (AM)', 'ALTA FLORESTA (MT)') 16945
# ('MANAUS (AM)', 'ALTAMIRA (PA)') 16944
# ('MANAUS (AM)', 'BELEM (PA)') 16943
# ('MANAUS (AM)', 'BOA VISTA (RR)') 16942
# ('MANAUS (AM)', 'BRASILIA (DF)') 16941
# ('MANAUS (AM)', 'CABO FRIO (RJ)') 16940
# ('MANAUS (AM)', 'CAMPINAS (SP)') 16939
# ('MANAUS (AM)', 'CONFINS (MG)') 16938
# ('MANAUS (AM)', 'FORTALEZA (CE)') 16937
# ('MANAUS (AM)', 'GOIANIA (GO)') 16936
# ('MANAUS (AM)', 'GUARULHOS (SP)') 16935
# ('MANAUS (AM)', 'ITAITUBA (PA)') 16934
# ('MANAUS (AM)', 'JUNDIAI (SP)') 16933
# ('MANAUS (AM)', 'VARZEA GRANDE (MT)') 16932
# ('MANAUS (AM)', 'MARABA (PA)') 16931
# ('MANAUS (AM)', 'RECIFE (PE)') 16930
# ('MANAUS (AM)', 'SANTAREM (PA)') 16929
# ('MANAUS (AM)', 'MACAPA (AP)') 16928
# ('MANAUS (AM)', 'VITORIA (ES)') 16927
# ('MANAUS (AM)', 'ORIXIMINA (PA)') 16926
# ('MANAUS (AM)', 'SAO GABRIEL DA CACHOEIRA (AM)') 16925
# ('MANAUS (AM)', 'SAO JOSE DOS CAMPOS (SP)') 16924
# ('MANAUS (AM)', 'SAO GONCALO DO AMARANTE (RN)') 16923
# ('MANAUS (AM)', 'RIO DE JANEIRO (RJ)') 16922
# ('MANAUS (AM)', 'SAO LUIS (MA)') 16921
# ('MANAUS (AM)', 'SAO JOSE DOS PINHAIS (PR)') 16920
# ('MANAUS (AM)', 'RIBEIRAO PRETO (SP)') 16919
# ('MANAUS (AM)', 'PARNAMIRIM (RN)') 16918
# ('MANAUS (AM)', 'SAO CARLOS (SP)') 16917
# ('MANAUS (AM)', 'PORTO ALEGRE (RS)') 16916
# ('MANAUS (AM)', 'UBERLANDIA (MG)') 16915
# ('FONTE BOA (AM)', 'JAPURA (AM)') 16914
# ('FONTE BOA (AM)', 'TONANTINS (AM)') 16913
# ('JAPURA (AM)', 'SAO GABRIEL DA CACHOEIRA (AM)') 16912
# ('JAPURA (AM)', 'TONANTINS (AM)') 16911
# ('ITAPIRANGA (AM)', 'PRESIDENTE FIGUEIREDO (AM)') 16910
# ('ITAPIRANGA (AM)', 'RIO PRETO DA EVA (AM)') 16909
# ('ITAPIRANGA (AM)', 'SAO SEBASTIAO DO UATUMA (AM)') 16908
# ('ITAPIRANGA (AM)', 'SILVES (AM)') 16907
# ('ITAPIRANGA (AM)', 'URUCARA (AM)') 16906
# ('RIO PRETO DA EVA (AM)', 'PRESIDENTE FIGUEIREDO (AM)') 16905
# ('PRESIDENTE FIGUEIREDO (AM)', 'SAO SEBASTIAO DO UATUMA (AM)') 16904
# ('PRESIDENTE FIGUEIREDO (AM)', 'URUCARA (AM)') 16903
# ('SAO SEBASTIAO DO UATUMA (AM)', 'URUCARA (AM)') 16902
# ('URUCARA (AM)', 'NHAMUNDA (AM)') 16901
# ('URUCARA (AM)', 'CAROEBE (RR)') 16900
# ('URUCARA (AM)', 'SAO JOAO DA BALIZA (RR)') 16899
# ('ITAITUBA (PA)', 'ALTAMIRA (PA)') 16898
# ('ITAITUBA (PA)', 'NOVO PROGRESSO (PA)') 16897
# ('ITAITUBA (PA)', 'RUROPOLIS (PA)') 16896
# ('ITAITUBA (PA)', 'TRAIRAO (PA)') 16895
# ('ITAITUBA (PA)', 'OBIDOS (PA)') 16894
# ('ITAITUBA (PA)', 'ALENQUER (PA)') 16893
# ('ITAITUBA (PA)', 'BELEM (PA)') 16892
# ('ITAITUBA (PA)', 'BREJO (MA)') 16891
# ('ITAITUBA (PA)', 'SANTAREM (PA)') 16890
# ('ITAITUBA (PA)', 'MONTE ALEGRE (PA)') 16889
# ('ITAITUBA (PA)', 'ORIXIMINA (PA)') 16888
# ('NHAMUNDA (AM)', 'CAROEBE (RR)') 16887
# ('NHAMUNDA (AM)', 'FARO (PA)') 16886
# ('NHAMUNDA (AM)', 'JURUTI (PA)') 16885
# ('NHAMUNDA (AM)', 'ORIXIMINA (PA)') 16884
# ('NHAMUNDA (AM)', 'TERRA SANTA (PA)') 16883
# ('CAROEBE (RR)', 'SAO JOAO DA BALIZA (RR)') 16882
# ('CAROEBE (RR)', 'ORIXIMINA (PA)') 16881
# ('FARO (PA)', 'ORIXIMINA (PA)') 16880
# ('FARO (PA)', 'TERRA SANTA (PA)') 16879
# ('JURUTI (PA)', 'OBIDOS (PA)') 16878
# ('JURUTI (PA)', 'ORIXIMINA (PA)') 16877
# ('JURUTI (PA)', 'SANTAREM (PA)') 16876
# ('JURUTI (PA)', 'TERRA SANTA (PA)') 16875
# ('ORIXIMINA (PA)', 'OBIDOS (PA)') 16874
# ('ORIXIMINA (PA)', 'TERRA SANTA (PA)') 16873
# ('ORIXIMINA (PA)', 'ALENQUER (PA)') 16872
# ('ORIXIMINA (PA)', 'BELO HORIZONTE (MG)') 16871
# ('ORIXIMINA (PA)', 'MARABA (PA)') 16870
# ('ORIXIMINA (PA)', 'MONTE ALEGRE (PA)') 16869
# ('ORIXIMINA (PA)', 'BREJO (MA)') 16868
# ('ORIXIMINA (PA)', 'SANTAREM (PA)') 16867
# ('SAO JOAO DA BALIZA (RR)', 'SAO LUIZ (RR)') 16866
# ('AMAJARI (RR)', 'ALTO ALEGRE (RR)') 16865
# ('AMAJARI (RR)', 'BOA VISTA (RR)') 16864
# ('AMAJARI (RR)', 'PACARAIMA (RR)') 16863
# ('ALTO ALEGRE (RR)', 'BOA VISTA (RR)') 16862
# ('ALTO ALEGRE (RR)', 'MUCAJAI (RR)') 16861
# ('BOA VISTA (RR)', 'BONFIM (RR)') 16860
# ('BOA VISTA (RR)', 'CANTA (RR)') 16859
# ('BOA VISTA (RR)', 'MUCAJAI (RR)') 16858
# ('BOA VISTA (RR)', 'NORMANDIA (RR)') 16857
# ('BOA VISTA (RR)', 'PACARAIMA (RR)') 16856
# ('BOA VISTA (RR)', 'BELEM (PA)') 16855
# ('BOA VISTA (RR)', 'CAMPINAS (SP)') 16854
# ('BOA VISTA (RR)', 'BRASILIA (DF)') 16853
# ('BOA VISTA (RR)', 'CONFINS (MG)') 16852
# ('BOA VISTA (RR)', 'GUARULHOS (SP)') 16851
# ('BOA VISTA (RR)', 'CAMPO GRANDE (MS)') 16850
# ('BOA VISTA (RR)', 'SAO JOSE DOS PINHAIS (PR)') 16849
# ('BOA VISTA (RR)', 'PORTO ALEGRE (RS)') 16848
# ('BOA VISTA (RR)', 'RIO DE JANEIRO (RJ)') 16847
# ('BOA VISTA (RR)', 'RECIFE (PE)') 16846
# ('BOA VISTA (RR)', 'VARZEA GRANDE (MT)') 16845
# ('BOA VISTA (RR)', 'FLORIANOPOLIS (SC)') 16844
# ('BOA VISTA (RR)', 'FORTALEZA (CE)') 16843
# ('BOA VISTA (RR)', 'SALVADOR (BA)') 16842
# ('PACARAIMA (RR)', 'NORMANDIA (RR)') 16841
# ('PACARAIMA (RR)', 'UIRAMUTA (RR)') 16840
# ('MUCAJAI (RR)', 'CANTA (RR)') 16839
# ('BONFIM (RR)', 'CANTA (RR)') 16838
# ('BONFIM (RR)', 'NORMANDIA (RR)') 16837
# ('NORMANDIA (RR)', 'UIRAMUTA (RR)') 16836
# ('ABAETETUBA (PA)', 'BARCARENA (PA)') 16835
# ('ABAETETUBA (PA)', 'IGARAPEMIRI (PA)') 16834
# ('ABAETETUBA (PA)', 'MOJU (PA)') 16833
# ('ABAETETUBA (PA)', 'MUANA (PA)') 16832
# ('ABAETETUBA (PA)', 'PONTA DE PEDRAS (PA)') 16831
# ('BARCARENA (PA)', 'ACARA (PA)') 16830
# ('BARCARENA (PA)', 'BELEM (PA)') 16829
# ('BARCARENA (PA)', 'MOJU (PA)') 16828
# ('BARCARENA (PA)', 'PONTA DE PEDRAS (PA)') 16827
# ('IGARAPEMIRI (PA)', 'CAMETA (PA)') 16826
# ('IGARAPEMIRI (PA)', 'LIMOEIRO DO AJURU (PA)') 16825
# ('IGARAPEMIRI (PA)', 'MOCAJUBA (PA)') 16824
# ('IGARAPEMIRI (PA)', 'MOJU (PA)') 16823
# ('IGARAPEMIRI (PA)', 'MUANA (PA)') 16822
# ('MOJU (PA)', 'ACARA (PA)') 16821
# ('MOJU (PA)', 'BAIAO (PA)') 16820
# ('MOJU (PA)', 'BREU BRANCO (PA)') 16819
# ('MOJU (PA)', 'IPIXUNA DO PARA (PA)') 16818
# ('MOJU (PA)', 'MOCAJUBA (PA)') 16817
# ('MOJU (PA)', 'TAILANDIA (PA)') 16816
# ('MUANA (PA)', 'ANAJAS (PA)') 16815
# ('MUANA (PA)', 'LIMOEIRO DO AJURU (PA)') 16814
# ('MUANA (PA)', 'PONTA DE PEDRAS (PA)') 16813
# ('MUANA (PA)', 'SAO SEBASTIAO DA BOA VISTA (PA)') 16812
# ('PONTA DE PEDRAS (PA)', 'ANAJAS (PA)') 16811
# ('PONTA DE PEDRAS (PA)', 'BELEM (PA)') 16810
# ('PONTA DE PEDRAS (PA)', 'CACHOEIRA DO ARARI (PA)') 16809
# ('PONTA DE PEDRAS (PA)', 'SANTA CRUZ DO ARARI (PA)') 16808
# ('ABEL FIGUEIREDO (PA)', 'BOM JESUS DO TOCANTINS (PA)') 16807
# ('ABEL FIGUEIREDO (PA)', 'RONDON DO PARA (PA)') 16806
# ('ABEL FIGUEIREDO (PA)', 'SAO PEDRO DA AGUA BRANCA (MA)') 16805
# ('ABEL FIGUEIREDO (PA)', 'VILA NOVA DOS MARTIRIOS (MA)') 16804
# ('BOM JESUS DO TOCANTINS (PA)', 'MARABA (PA)') 16803
# ('BOM JESUS DO TOCANTINS (PA)', 'RONDON DO PARA (PA)') 16802
# ('BOM JESUS DO TOCANTINS (PA)', 'SAO JOAO DO ARAGUAIA (PA)') 16801
# ('BOM JESUS DO TOCANTINS (PA)', 'ESPERANTINA (TO)') 16800
# ('BOM JESUS DO TOCANTINS (PA)', 'SAO PEDRO DA AGUA BRANCA (MA)') 16799
# ('RONDON DO PARA (PA)', 'DOM ELISEU (PA)') 16798
# ('RONDON DO PARA (PA)', 'GOIANESIA DO PARA (PA)') 16797
# ('RONDON DO PARA (PA)', 'JACUNDA (PA)') 16796
# ('RONDON DO PARA (PA)', 'MARABA (PA)') 16795
# ('RONDON DO PARA (PA)', 'NOVA IPIXUNA (PA)') 16794
# ('RONDON DO PARA (PA)', 'ACAILANDIA (MA)') 16793
# ('RONDON DO PARA (PA)', 'CIDELANDIA (MA)') 16792
# ('RONDON DO PARA (PA)', 'VILA NOVA DOS MARTIRIOS (MA)') 16791
# ('SAO PEDRO DA AGUA BRANCA (MA)', 'SAO JOAO DO ARAGUAIA (PA)') 16790
# ('SAO PEDRO DA AGUA BRANCA (MA)', 'ESPERANTINA (TO)') 16789
# ('SAO PEDRO DA AGUA BRANCA (MA)', 'SAO SEBASTIAO DO TOCANTINS (TO)') 16788
# ('SAO PEDRO DA AGUA BRANCA (MA)', 'VILA NOVA DOS MARTIRIOS (MA)') 16787
# ('VILA NOVA DOS MARTIRIOS (MA)', 'BURITI DO TOCANTINS (TO)') 16786
# ('VILA NOVA DOS MARTIRIOS (MA)', 'CARRASCO BONITO (TO)') 16785
# ('VILA NOVA DOS MARTIRIOS (MA)', 'SAMPAIO (TO)') 16784
# ('VILA NOVA DOS MARTIRIOS (MA)', 'SAO SEBASTIAO DO TOCANTINS (TO)') 16783
# ('VILA NOVA DOS MARTIRIOS (MA)', 'CIDELANDIA (MA)') 16782
# ('ACARA (PA)', 'BELEM (PA)') 16781
# ('ACARA (PA)', 'BENEVIDES (PA)') 16780
# ('ACARA (PA)', 'BUJARU (PA)') 16779
# ('ACARA (PA)', 'CONCORDIA DO PARA (PA)') 16778
# ('ACARA (PA)', 'MARITUBA (PA)') 16777
# ('ACARA (PA)', 'TAILANDIA (PA)') 16776
# ('ACARA (PA)', 'TOMEACU (PA)') 16775
# ('BELEM (PA)', 'ANANINDEUA (PA)') 16774
# ('BELEM (PA)', 'CACHOEIRA DO ARARI (PA)') 16773
# ('BELEM (PA)', 'MARITUBA (PA)') 16772
# ('BELEM (PA)', 'SANTA BARBARA DO PARA (PA)') 16771
# ('BELEM (PA)', 'SANTO ANTONIO DO TAUA (PA)') 16770
# ('BELEM (PA)', 'ALMEIRIM (PA)') 16769
# ('BELEM (PA)', 'ALTAMIRA (PA)') 16768
# ('BELEM (PA)', 'ARAGUAINA (TO)') 16767
# ('BELEM (PA)', 'CONFINS (MG)') 16766
# ('BELEM (PA)', 'PARAUAPEBAS (PA)') 16765
# ('BELEM (PA)', 'FORTALEZA (CE)') 16764
# ('BELEM (PA)', 'GUARULHOS (SP)') 16763
# ('BELEM (PA)', 'CAMPINAS (SP)') 16762
# ('BELEM (PA)', 'MARABA (PA)') 16761
# ('BELEM (PA)', 'MACAPA (AP)') 16760
# ('BELEM (PA)', 'RECIFE (PE)') 16759
# ('BELEM (PA)', 'SAO LUIS (MA)') 16758
# ('BELEM (PA)', 'SANTAREM (PA)') 16757
# ('BELEM (PA)', 'TERESINA (PI)') 16756
# ('BELEM (PA)', 'RIO DE JANEIRO (RJ)') 16755
# ('BELEM (PA)', 'IMPERATRIZ (MA)') 16754
# ('BELEM (PA)', 'RIBEIRAO PRETO (SP)') 16753
# ('BELEM (PA)', 'PORTO ALEGRE (RS)') 16752
# ('BELEM (PA)', 'BRASILIA (DF)') 16751
# ('BELEM (PA)', 'SAO JOSE DOS CAMPOS (SP)') 16750
# ('BELEM (PA)', 'SALVADOR (BA)') 16749
# ('BELEM (PA)', 'LONDRINA (PR)') 16748
# ('BELEM (PA)', 'PORTO DE MOZ (PA)') 16747
# ('BELEM (PA)', 'BREVES (PA)') 16746
# ('BELEM (PA)', 'REDENCAO (PA)') 16745
# ('BELEM (PA)', 'PALMAS (TO)') 16744
# ('BELEM (PA)', 'CHAVES (PA)') 16743
# ('BELEM (PA)', 'PARAGOMINAS (PA)') 16742
# ('BELEM (PA)', 'JUNDIAI (SP)') 16741
# ('BELEM (PA)', 'VARZEA GRANDE (MT)') 16740
# ('BELEM (PA)', 'TUCURUI (PA)') 16739
# ('BELEM (PA)', 'SAO JOSE DOS PINHAIS (PR)') 16738
# ('BELEM (PA)', 'GOIANIA (GO)') 16737
# ('BELEM (PA)', 'VITORIA (ES)') 16736
# ('BELEM (PA)', 'FLORIANOPOLIS (SC)') 16735
# ('BELEM (PA)', 'SAO GONCALO DO AMARANTE (RN)') 16734
# ('BENEVIDES (PA)', 'ANANINDEUA (PA)') 16733
# ('BENEVIDES (PA)', 'BUJARU (PA)') 16732
# ('BENEVIDES (PA)', 'MARITUBA (PA)') 16731
# ('BENEVIDES (PA)', 'SANTA BARBARA DO PARA (PA)') 16730
# ('BENEVIDES (PA)', 'SANTA IZABEL DO PARA (PA)') 16729
# ('BUJARU (PA)', 'CONCORDIA DO PARA (PA)') 16728
# ('BUJARU (PA)', 'INHANGAPI (PA)') 16727
# ('BUJARU (PA)', 'MARITUBA (PA)') 16726
# ('BUJARU (PA)', 'SANTA IZABEL DO PARA (PA)') 16725
# ('BUJARU (PA)', 'SAO DOMINGOS DO CAPIM (PA)') 16724
# ('BUJARU (PA)', 'SAO MIGUEL DO GUAMA (PA)') 16723
# ('CONCORDIA DO PARA (PA)', 'SAO DOMINGOS DO CAPIM (PA)') 16722
# ('CONCORDIA DO PARA (PA)', 'TOMEACU (PA)') 16721
# ('MARITUBA (PA)', 'ANANINDEUA (PA)') 16720
# ('TAILANDIA (PA)', 'IPIXUNA DO PARA (PA)') 16719
# ('TAILANDIA (PA)', 'TOMEACU (PA)') 16718
# ('TOMEACU (PA)', 'AURORA DO PARA (PA)') 16717
# ('TOMEACU (PA)', 'IPIXUNA DO PARA (PA)') 16716
# ('TOMEACU (PA)', 'SAO DOMINGOS DO CAPIM (PA)') 16715
# ('AFUA (PA)', 'ANAJAS (PA)') 16714
# ('AFUA (PA)', 'BREVES (PA)') 16713
# ('AFUA (PA)', 'CHAVES (PA)') 16712
# ('AFUA (PA)', 'GURUPA (PA)') 16711
# ('AFUA (PA)', 'ITAUBAL (AP)') 16710
# ('AFUA (PA)', 'MACAPA (AP)') 16709
# ('AFUA (PA)', 'MAZAGAO (AP)') 16708
# ('AFUA (PA)', 'SANTANA (AP)') 16707
# ('ANAJAS (PA)', 'BREVES (PA)') 16706
# ('ANAJAS (PA)', 'CHAVES (PA)') 16705
# ('ANAJAS (PA)', 'SANTA CRUZ DO ARARI (PA)') 16704
# ('ANAJAS (PA)', 'SAO SEBASTIAO DA BOA VISTA (PA)') 16703
# ('BREVES (PA)', 'BAGRE (PA)') 16702
# ('BREVES (PA)', 'CURRALINHO (PA)') 16701
# ('BREVES (PA)', 'GURUPA (PA)') 16700
# ('BREVES (PA)', 'MELGACO (PA)') 16699
# ('BREVES (PA)', 'SAO SEBASTIAO DA BOA VISTA (PA)') 16698
# ('BREVES (PA)', 'ALMEIRIM (PA)') 16697
# ('BREVES (PA)', 'ALTAMIRA (PA)') 16696
# ('BREVES (PA)', 'PORTO DE MOZ (PA)') 16695
# ('BREVES (PA)', 'SANTAREM (PA)') 16694
# ('BREVES (PA)', 'MACAPA (AP)') 16693
# ('CHAVES (PA)', 'CACHOEIRA DO ARARI (PA)') 16692
# ('CHAVES (PA)', 'SANTA CRUZ DO ARARI (PA)') 16691
# ('CHAVES (PA)', 'SOURE (PA)') 16690
# ('CHAVES (PA)', 'ITAUBAL (AP)') 16689
# ('CHAVES (PA)', 'MACAPA (AP)') 16688
# ('GURUPA (PA)', 'ALMEIRIM (PA)') 16687
# ('GURUPA (PA)', 'MELGACO (PA)') 16686
# ('GURUPA (PA)', 'PORTO DE MOZ (PA)') 16685
# ('GURUPA (PA)', 'MAZAGAO (AP)') 16684
# ('GURUPA (PA)', 'VITORIA DO JARI (AP)') 16683
# ('ITAUBAL (AP)', 'MACAPA (AP)') 16682
# ('MACAPA (AP)', 'AMAPA (AP)') 16681
# ('MACAPA (AP)', 'CUTIAS (AP)') 16680
# ('MACAPA (AP)', 'FERREIRA GOMES (AP)') 16679
# ('MACAPA (AP)', 'PORTO GRANDE (AP)') 16678
# ('MACAPA (AP)', 'SANTANA (AP)') 16677
# ('MACAPA (AP)', 'ALMEIRIM (PA)') 16676
# ('MACAPA (AP)', 'BRASILIA (DF)') 16675
# ('MACAPA (AP)', 'CAMPINAS (SP)') 16674
# ('MACAPA (AP)', 'CONFINS (MG)') 16673
# ('MACAPA (AP)', 'FORTALEZA (CE)') 16672
# ('MACAPA (AP)', 'GUARULHOS (SP)') 16671
# ('MACAPA (AP)', 'RECIFE (PE)') 16670
# ('MACAPA (AP)', 'PORTO DE MOZ (PA)') 16669
# ('MACAPA (AP)', 'ALTAMIRA (PA)') 16668
# ('MACAPA (AP)', 'SAO PAULO (SP)') 16667
# ('MACAPA (AP)', 'PARAUAPEBAS (PA)') 16666
# ('MACAPA (AP)', 'GOIANIA (GO)') 16665
# ('MACAPA (AP)', 'SANTAREM (PA)') 16664
# ('MAZAGAO (AP)', 'PEDRA BRANCA DO AMAPARI (AP)') 16663
# ('MAZAGAO (AP)', 'LARANJAL DO JARI (AP)') 16662
# ('MAZAGAO (AP)', 'PORTO GRANDE (AP)') 16661
# ('MAZAGAO (AP)', 'SANTANA (AP)') 16660
# ('MAZAGAO (AP)', 'VITORIA DO JARI (AP)') 16659
# ('SANTANA (AP)', 'PORTO GRANDE (AP)') 16658
# ('AGUA AZUL DO NORTE (PA)', 'BANNACH (PA)') 16657
# ('AGUA AZUL DO NORTE (PA)', 'CANAA DOS CARAJAS (PA)') 16656
# ('AGUA AZUL DO NORTE (PA)', 'CURIONOPOLIS (PA)') 16655
# ('AGUA AZUL DO NORTE (PA)', 'OURILANDIA DO NORTE (PA)') 16654
# ('AGUA AZUL DO NORTE (PA)', 'PARAUAPEBAS (PA)') 16653
# ('AGUA AZUL DO NORTE (PA)', 'RIO MARIA (PA)') 16652
# ('AGUA AZUL DO NORTE (PA)', 'SAPUCAIA (PA)') 16651
# ('AGUA AZUL DO NORTE (PA)', 'XINGUARA (PA)') 16650
# ('BANNACH (PA)', 'CUMARU DO NORTE (PA)') 16649
# ('BANNACH (PA)', 'OURILANDIA DO NORTE (PA)') 16648
# ('BANNACH (PA)', 'PAU DARCO (PA)') 16647
# ('BANNACH (PA)', 'REDENCAO (PA)') 16646
# ('BANNACH (PA)', 'RIO MARIA (PA)') 16645
# ('BANNACH (PA)', 'XINGUARA (PA)') 16644
# ('CANAA DOS CARAJAS (PA)', 'CURIONOPOLIS (PA)') 16643
# ('CANAA DOS CARAJAS (PA)', 'PARAUAPEBAS (PA)') 16642
# ('CANAA DOS CARAJAS (PA)', 'SAPUCAIA (PA)') 16641
# ('CURIONOPOLIS (PA)', 'ELDORADO DO CARAJAS (PA)') 16640
# ('CURIONOPOLIS (PA)', 'MARABA (PA)') 16639
# ('CURIONOPOLIS (PA)', 'PARAUAPEBAS (PA)') 16638
# ('CURIONOPOLIS (PA)', 'PICARRA (PA)') 16637
# ('CURIONOPOLIS (PA)', 'SAPUCAIA (PA)') 16636
# ('CURIONOPOLIS (PA)', 'XINGUARA (PA)') 16635
# ('OURILANDIA DO NORTE (PA)', 'CUMARU DO NORTE (PA)') 16634
# ('OURILANDIA DO NORTE (PA)', 'PARAUAPEBAS (PA)') 16633
# ('OURILANDIA DO NORTE (PA)', 'SAO FELIX DO XINGU (PA)') 16632
# ('OURILANDIA DO NORTE (PA)', 'TUCUMA (PA)') 16631
# ('PARAUAPEBAS (PA)', 'MARABA (PA)') 16630
# ('PARAUAPEBAS (PA)', 'SAO FELIX DO XINGU (PA)') 16629
# ('PARAUAPEBAS (PA)', 'BELO HORIZONTE (MG)') 16628
# ('PARAUAPEBAS (PA)', 'BRASILIA (DF)') 16627
# ('PARAUAPEBAS (PA)', 'CAMPINAS (SP)') 16626
# ('PARAUAPEBAS (PA)', 'CONFINS (MG)') 16625
# ('PARAUAPEBAS (PA)', 'GUARULHOS (SP)') 16624
# ('PARAUAPEBAS (PA)', 'PORTO SEGURO (BA)') 16623
# ('PARAUAPEBAS (PA)', 'SAO LUIS (MA)') 16622
# ('PARAUAPEBAS (PA)', 'RIO DE JANEIRO (RJ)') 16621
# ('PARAUAPEBAS (PA)', 'RIBEIRAO PRETO (SP)') 16620
# ('PARAUAPEBAS (PA)', 'FORTALEZA (CE)') 16619
# ('RIO MARIA (PA)', 'FLORESTA DO ARAGUAIA (PA)') 16618
# ('RIO MARIA (PA)', 'PAU DARCO (PA)') 16617
# ('RIO MARIA (PA)', 'XINGUARA (PA)') 16616
# ('RIO MARIA (PA)', 'SANTA FE DO ARAGUAIA (TO)') 16615
# ('SAPUCAIA (PA)', 'XINGUARA (PA)') 16614
# ('XINGUARA (PA)', 'ELDORADO DO CARAJAS (PA)') 16613
# ('XINGUARA (PA)', 'PICARRA (PA)') 16612
# ('XINGUARA (PA)', 'SANTA FE DO ARAGUAIA (TO)') 16611
# ('ALENQUER (PA)', 'ALMEIRIM (PA)') 16610
# ('ALENQUER (PA)', 'CURUA (PA)') 16609
# ('ALENQUER (PA)', 'MONTE ALEGRE (PA)') 16608
# ('ALENQUER (PA)', 'OBIDOS (PA)') 16607
# ('ALENQUER (PA)', 'SANTAREM (PA)') 16606
# ('ALENQUER (PA)', 'BREJO (MA)') 16605
# ('ALMEIRIM (PA)', 'MONTE ALEGRE (PA)') 16604
# ('ALMEIRIM (PA)', 'OBIDOS (PA)') 16603
# ('ALMEIRIM (PA)', 'PORTO DE MOZ (PA)') 16602
# ('ALMEIRIM (PA)', 'PRAINHA (PA)') 16601
# ('ALMEIRIM (PA)', 'LARANJAL DO JARI (AP)') 16600
# ('ALMEIRIM (PA)', 'VITORIA DO JARI (AP)') 16599
# ('ALMEIRIM (PA)', 'ALTAMIRA (PA)') 16598
# ('ALMEIRIM (PA)', 'SANTAREM (PA)') 16597
# ('CURUA (PA)', 'OBIDOS (PA)') 16596
# ('CURUA (PA)', 'SANTAREM (PA)') 16595
# ('MONTE ALEGRE (PA)', 'PRAINHA (PA)') 16594
# ('MONTE ALEGRE (PA)', 'SANTAREM (PA)') 16593
# ('MONTE ALEGRE (PA)', 'BREJO (MA)') 16592
# ('MONTE ALEGRE (PA)', 'OBIDOS (PA)') 16591
# ('OBIDOS (PA)', 'SANTAREM (PA)') 16590
# ('OBIDOS (PA)', 'BREJO (MA)') 16589
# ('SANTAREM (PA)', 'BELTERRA (PA)') 16588
# ('SANTAREM (PA)', 'MOJUI DOS CAMPOS (PA)') 16587
# ('SANTAREM (PA)', 'PRAINHA (PA)') 16586
# ('SANTAREM (PA)', 'URUARA (PA)') 16585
# ('SANTAREM (PA)', 'ALTAMIRA (PA)') 16584
# ('SANTAREM (PA)', 'BRASILIA (DF)') 16583
# ('SANTAREM (PA)', 'BREJO (MA)') 16582
# ('SANTAREM (PA)', 'CAMPINAS (SP)') 16581
# ('SANTAREM (PA)', 'CONFINS (MG)') 16580
# ('SANTAREM (PA)', 'FORTALEZA (CE)') 16579
# ('SANTAREM (PA)', 'GUARULHOS (SP)') 16578
# ('SANTAREM (PA)', 'MARABA (PA)') 16577
# ('SANTAREM (PA)', 'PALMAS (TO)') 16576
# ('SANTAREM (PA)', 'PORTO DE MOZ (PA)') 16575
# ('SANTAREM (PA)', 'RECIFE (PE)') 16574
# ('SANTAREM (PA)', 'RIO DE JANEIRO (RJ)') 16573
# ('SANTAREM (PA)', 'SALVADOR (BA)') 16572
# ('SANTAREM (PA)', 'SAO LUIS (MA)') 16571
# ('PORTO DE MOZ (PA)', 'BRASIL NOVO (PA)') 16570
# ('PORTO DE MOZ (PA)', 'MEDICILANDIA (PA)') 16569
# ('PORTO DE MOZ (PA)', 'MELGACO (PA)') 16568
# ('PORTO DE MOZ (PA)', 'PORTEL (PA)') 16567
# ('PORTO DE MOZ (PA)', 'PRAINHA (PA)') 16566
# ('PORTO DE MOZ (PA)', 'SENADOR JOSE PORFIRIO (PA)') 16565
# ('PORTO DE MOZ (PA)', 'VITORIA DO XINGU (PA)') 16564
# ('PORTO DE MOZ (PA)', 'ALTAMIRA (PA)') 16563
# ('PRAINHA (PA)', 'MEDICILANDIA (PA)') 16562
# ('PRAINHA (PA)', 'URUARA (PA)') 16561
# ('LARANJAL DO JARI (AP)', 'PEDRA BRANCA DO AMAPARI (AP)') 16560
# ('LARANJAL DO JARI (AP)', 'OIAPOQUE (AP)') 16559
# ('LARANJAL DO JARI (AP)', 'VITORIA DO JARI (AP)') 16558
# ('ALTAMIRA (PA)', 'BRASIL NOVO (PA)') 16557
# ('ALTAMIRA (PA)', 'NOVO PROGRESSO (PA)') 16556
# ('ALTAMIRA (PA)', 'PLACAS (PA)') 16555
# ('ALTAMIRA (PA)', 'RUROPOLIS (PA)') 16554
# ('ALTAMIRA (PA)', 'SAO FELIX DO XINGU (PA)') 16553
# ('ALTAMIRA (PA)', 'SENADOR JOSE PORFIRIO (PA)') 16552
# ('ALTAMIRA (PA)', 'TRAIRAO (PA)') 16551
# ('ALTAMIRA (PA)', 'URUARA (PA)') 16550
# ('ALTAMIRA (PA)', 'VITORIA DO XINGU (PA)') 16549
# ('ALTAMIRA (PA)', 'GUARANTA DO NORTE (MT)') 16548
# ('ALTAMIRA (PA)', 'MATUPA (MT)') 16547
# ('ALTAMIRA (PA)', 'PEIXOTO DE AZEVEDO (MT)') 16546
# ('ALTAMIRA (PA)', 'SAO LUIS (MA)') 16545
# ('ALTAMIRA (PA)', 'CAMPINAS (SP)') 16544
# ('BRASIL NOVO (PA)', 'MEDICILANDIA (PA)') 16543
# ('BRASIL NOVO (PA)', 'URUARA (PA)') 16542
# ('BRASIL NOVO (PA)', 'VITORIA DO XINGU (PA)') 16541
# ('NOVO PROGRESSO (PA)', 'ALTA FLORESTA (MT)') 16540
# ('NOVO PROGRESSO (PA)', 'GUARANTA DO NORTE (MT)') 16539
# ('NOVO PROGRESSO (PA)', 'NOVO MUNDO (MT)') 16538
# ('PLACAS (PA)', 'BELTERRA (PA)') 16537
# ('PLACAS (PA)', 'MOJUI DOS CAMPOS (PA)') 16536
# ('PLACAS (PA)', 'RUROPOLIS (PA)') 16535
# ('PLACAS (PA)', 'URUARA (PA)') 16534
# ('RUROPOLIS (PA)', 'BELTERRA (PA)') 16533
# ('SAO FELIX DO XINGU (PA)', 'ANAPU (PA)') 16532
# ('SAO FELIX DO XINGU (PA)', 'CUMARU DO NORTE (PA)') 16531
# ('SAO FELIX DO XINGU (PA)', 'MARABA (PA)') 16530
# ('SAO FELIX DO XINGU (PA)', 'NOVO REPARTIMENTO (PA)') 16529
# ('SAO FELIX DO XINGU (PA)', 'SANTANA DO ARAGUAIA (PA)') 16528
# ('SAO FELIX DO XINGU (PA)', 'SENADOR JOSE PORFIRIO (PA)') 16527
# ('SAO FELIX DO XINGU (PA)', 'TUCUMA (PA)') 16526
# ('SAO FELIX DO XINGU (PA)', 'PEIXOTO DE AZEVEDO (MT)') 16525
# ('SAO FELIX DO XINGU (PA)', 'SANTA CRUZ DO XINGU (MT)') 16524
# ('SAO FELIX DO XINGU (PA)', 'VILA RICA (MT)') 16523
# ('SENADOR JOSE PORFIRIO (PA)', 'ANAPU (PA)') 16522
# ('SENADOR JOSE PORFIRIO (PA)', 'PORTEL (PA)') 16521
# ('SENADOR JOSE PORFIRIO (PA)', 'VITORIA DO XINGU (PA)') 16520
# ('URUARA (PA)', 'MEDICILANDIA (PA)') 16519
# ('URUARA (PA)', 'MOJUI DOS CAMPOS (PA)') 16518
# ('VITORIA DO XINGU (PA)', 'ANAPU (PA)') 16517
# ('GUARANTA DO NORTE (MT)', 'MATUPA (MT)') 16516
# ('GUARANTA DO NORTE (MT)', 'NOVO MUNDO (MT)') 16515
# ('MATUPA (MT)', 'NOVO MUNDO (MT)') 16514
# ('MATUPA (MT)', 'PEIXOTO DE AZEVEDO (MT)') 16513
# ('MATUPA (MT)', 'TERRA NOVA DO NORTE (MT)') 16512
# ('MATUPA (MT)', 'NOVA GUARITA (MT)') 16511
# ('PEIXOTO DE AZEVEDO (MT)', 'MARCELANDIA (MT)') 16510
# ('PEIXOTO DE AZEVEDO (MT)', 'NOVA SANTA HELENA (MT)') 16509
# ('PEIXOTO DE AZEVEDO (MT)', 'SAO JOSE DO XINGU (MT)') 16508
# ('PEIXOTO DE AZEVEDO (MT)', 'SANTA CRUZ DO XINGU (MT)') 16507
# ('PEIXOTO DE AZEVEDO (MT)', 'TERRA NOVA DO NORTE (MT)') 16506
# ('SANTA CRUZ DO ARARI (PA)', 'CACHOEIRA DO ARARI (PA)') 16505
# ('SAO SEBASTIAO DA BOA VISTA (PA)', 'CURRALINHO (PA)') 16504
# ('SAO SEBASTIAO DA BOA VISTA (PA)', 'LIMOEIRO DO AJURU (PA)') 16503
# ('ANANINDEUA (PA)', 'SANTA BARBARA DO PARA (PA)') 16502
# ('SANTA BARBARA DO PARA (PA)', 'SANTA IZABEL DO PARA (PA)') 16501
# ('SANTA BARBARA DO PARA (PA)', 'SANTO ANTONIO DO TAUA (PA)') 16500
# ('ANAPU (PA)', 'NOVO REPARTIMENTO (PA)') 16499
# ('ANAPU (PA)', 'PACAJA (PA)') 16498
# ('ANAPU (PA)', 'PORTEL (PA)') 16497
# ('NOVO REPARTIMENTO (PA)', 'BREU BRANCO (PA)') 16496
# ('NOVO REPARTIMENTO (PA)', 'GOIANESIA DO PARA (PA)') 16495
# ('NOVO REPARTIMENTO (PA)', 'ITUPIRANGA (PA)') 16494
# ('NOVO REPARTIMENTO (PA)', 'JACUNDA (PA)') 16493
# ('NOVO REPARTIMENTO (PA)', 'MARABA (PA)') 16492
# ('NOVO REPARTIMENTO (PA)', 'PACAJA (PA)') 16491
# ('NOVO REPARTIMENTO (PA)', 'TUCURUI (PA)') 16490
# ('PACAJA (PA)', 'BAIAO (PA)') 16489
# ('PACAJA (PA)', 'PORTEL (PA)') 16488
# ('PACAJA (PA)', 'TUCURUI (PA)') 16487
# ('PORTEL (PA)', 'BAGRE (PA)') 16486
# ('PORTEL (PA)', 'BAIAO (PA)') 16485
# ('PORTEL (PA)', 'MELGACO (PA)') 16484
# ('AUGUSTO CORREA (PA)', 'BRAGANCA (PA)') 16483
# ('AUGUSTO CORREA (PA)', 'VISEU (PA)') 16482
# ('BRAGANCA (PA)', 'SANTA LUZIA DO PARA (PA)') 16481
# ('BRAGANCA (PA)', 'TRACUATEUA (PA)') 16480
# ('BRAGANCA (PA)', 'VISEU (PA)') 16479
# ('VISEU (PA)', 'CACHOEIRA DO PIRIA (PA)') 16478
# ('VISEU (PA)', 'NOVA ESPERANCA DO PIRIA (PA)') 16477
# ('VISEU (PA)', 'SANTA LUZIA DO PARA (PA)') 16476
# ('VISEU (PA)', 'BOA VISTA DO GURUPI (MA)') 16475
# ('VISEU (PA)', 'CARUTAPERA (MA)') 16474
# ('AURORA DO PARA (PA)', 'CAPITAO POCO (PA)') 16473
# ('AURORA DO PARA (PA)', 'IPIXUNA DO PARA (PA)') 16472
# ('AURORA DO PARA (PA)', 'MAE DO RIO (PA)') 16471
# ('AURORA DO PARA (PA)', 'SAO DOMINGOS DO CAPIM (PA)') 16470
# ('CAPITAO POCO (PA)', 'GARRAFAO DO NORTE (PA)') 16469
# ('CAPITAO POCO (PA)', 'IPIXUNA DO PARA (PA)') 16468
# ('CAPITAO POCO (PA)', 'IRITUIA (PA)') 16467
# ('CAPITAO POCO (PA)', 'MAE DO RIO (PA)') 16466
# ('CAPITAO POCO (PA)', 'NOVA ESPERANCA DO PIRIA (PA)') 16465
# ('CAPITAO POCO (PA)', 'OUREM (PA)') 16464
# ('CAPITAO POCO (PA)', 'SANTA LUZIA DO PARA (PA)') 16463
# ('IPIXUNA DO PARA (PA)', 'BREU BRANCO (PA)') 16462
# ('IPIXUNA DO PARA (PA)', 'GOIANESIA DO PARA (PA)') 16461
# ('IPIXUNA DO PARA (PA)', 'NOVA ESPERANCA DO PIRIA (PA)') 16460
# ('IPIXUNA DO PARA (PA)', 'PARAGOMINAS (PA)') 16459
# ('MAE DO RIO (PA)', 'IRITUIA (PA)') 16458
# ('MAE DO RIO (PA)', 'SAO DOMINGOS DO CAPIM (PA)') 16457
# ('SAO DOMINGOS DO CAPIM (PA)', 'IRITUIA (PA)') 16456
# ('SAO DOMINGOS DO CAPIM (PA)', 'SAO MIGUEL DO GUAMA (PA)') 16455
# ('BELTERRA (PA)', 'MOJUI DOS CAMPOS (PA)') 16454
# ('BAGRE (PA)', 'BAIAO (PA)') 16453
# ('BAGRE (PA)', 'CURRALINHO (PA)') 16452
# ('BAGRE (PA)', 'MELGACO (PA)') 16451
# ('BAGRE (PA)', 'OEIRAS DO PARA (PA)') 16450
# ('BAIAO (PA)', 'BREU BRANCO (PA)') 16449
# ('BAIAO (PA)', 'MOCAJUBA (PA)') 16448
# ('BAIAO (PA)', 'OEIRAS DO PARA (PA)') 16447
# ('BAIAO (PA)', 'TUCURUI (PA)') 16446
# ('CURRALINHO (PA)', 'LIMOEIRO DO AJURU (PA)') 16445
# ('CURRALINHO (PA)', 'OEIRAS DO PARA (PA)') 16444
# ('OEIRAS DO PARA (PA)', 'CAMETA (PA)') 16443
# ('OEIRAS DO PARA (PA)', 'LIMOEIRO DO AJURU (PA)') 16442
# ('OEIRAS DO PARA (PA)', 'MOCAJUBA (PA)') 16441
# ('BREU BRANCO (PA)', 'GOIANESIA DO PARA (PA)') 16440
# ('BREU BRANCO (PA)', 'TUCURUI (PA)') 16439
# ('MOCAJUBA (PA)', 'CAMETA (PA)') 16438
# ('TUCURUI (PA)', 'GOIANESIA DO PARA (PA)') 16437
# ('CUMARU DO NORTE (PA)', 'REDENCAO (PA)') 16436
# ('CUMARU DO NORTE (PA)', 'SANTA MARIA DAS BARREIRAS (PA)') 16435
# ('CUMARU DO NORTE (PA)', 'SANTANA DO ARAGUAIA (PA)') 16434
# ('PAU DARCO (PA)', 'FLORESTA DO ARAGUAIA (PA)') 16433
# ('PAU DARCO (PA)', 'REDENCAO (PA)') 16432
# ('REDENCAO (PA)', 'CONCEICAO DO ARAGUAIA (PA)') 16431
# ('REDENCAO (PA)', 'FLORESTA DO ARAGUAIA (PA)') 16430
# ('REDENCAO (PA)', 'SANTA MARIA DAS BARREIRAS (PA)') 16429
# ('CACHOEIRA DO ARARI (PA)', 'COLARES (PA)') 16428
# ('CACHOEIRA DO ARARI (PA)', 'SALVATERRA (PA)') 16427
# ('CACHOEIRA DO ARARI (PA)', 'SANTO ANTONIO DO TAUA (PA)') 16426
# ('CACHOEIRA DO ARARI (PA)', 'SOURE (PA)') 16425
# ('SANTO ANTONIO DO TAUA (PA)', 'CASTANHAL (PA)') 16424
# ('SANTO ANTONIO DO TAUA (PA)', 'COLARES (PA)') 16423
# ('SANTO ANTONIO DO TAUA (PA)', 'SANTA IZABEL DO PARA (PA)') 16422
# ('SANTO ANTONIO DO TAUA (PA)', 'VIGIA (PA)') 16421
# ('SANTA IZABEL DO PARA (PA)', 'CASTANHAL (PA)') 16420
# ('SANTA IZABEL DO PARA (PA)', 'INHANGAPI (PA)') 16419
# ('MARABA (PA)', 'ELDORADO DO CARAJAS (PA)') 16418
# ('MARABA (PA)', 'ITUPIRANGA (PA)') 16417
# ('MARABA (PA)', 'NOVA IPIXUNA (PA)') 16416
# ('MARABA (PA)', 'SAO DOMINGOS DO ARAGUAIA (PA)') 16415
# ('MARABA (PA)', 'SAO GERALDO DO ARAGUAIA (PA)') 16414
# ('MARABA (PA)', 'SAO JOAO DO ARAGUAIA (PA)') 16413
# ('MARABA (PA)', 'BELO HORIZONTE (MG)') 16412
# ('MARABA (PA)', 'BRASILIA (DF)') 16411
# ('MARABA (PA)', 'CAMPINAS (SP)') 16410
# ('MARABA (PA)', 'CONFINS (MG)') 16409
# ('MARABA (PA)', 'IMPERATRIZ (MA)') 16408
# ('MARABA (PA)', 'RECIFE (PE)') 16407
# ('MARABA (PA)', 'GUARULHOS (SP)') 16406
# ('MARABA (PA)', 'GOIANIA (GO)') 16405
# ('MARABA (PA)', 'RIO DE JANEIRO (RJ)') 16404
# ('MARABA (PA)', 'SAO LUIS (MA)') 16403
# ('SAO JOAO DO ARAGUAIA (PA)', 'BREJO GRANDE DO ARAGUAIA (PA)') 16402
# ('SAO JOAO DO ARAGUAIA (PA)', 'SAO DOMINGOS DO ARAGUAIA (PA)') 16401
# ('SAO JOAO DO ARAGUAIA (PA)', 'ARAGUATINS (TO)') 16400
# ('SAO JOAO DO ARAGUAIA (PA)', 'ESPERANTINA (TO)') 16399
# ('ESPERANTINA (TO)', 'ARAGUATINS (TO)') 16398
# ('ESPERANTINA (TO)', 'SAO SEBASTIAO DO TOCANTINS (TO)') 16397
# ('BONITO (PA)', 'CAPANEMA (PA)') 16396
# ('BONITO (PA)', 'NOVA TIMBOTEUA (PA)') 16395
# ('BONITO (PA)', 'OUREM (PA)') 16394
# ('BONITO (PA)', 'PEIXEBOI (PA)') 16393
# ('BONITO (PA)', 'SANTA MARIA DO PARA (PA)') 16392
# ('BONITO (PA)', 'SAO MIGUEL DO GUAMA (PA)') 16391
# ('BONITO (PA)', 'TRACUATEUA (PA)') 16390
# ('CAPANEMA (PA)', 'PEIXEBOI (PA)') 16389
# ('CAPANEMA (PA)', 'PRIMAVERA (PA)') 16388
# ('CAPANEMA (PA)', 'QUATIPURU (PA)') 16387
# ('CAPANEMA (PA)', 'TRACUATEUA (PA)') 16386
# ('NOVA TIMBOTEUA (PA)', 'IGARAPEACU (PA)') 16385
# ('NOVA TIMBOTEUA (PA)', 'PEIXEBOI (PA)') 16384
# ('NOVA TIMBOTEUA (PA)', 'SANTA MARIA DO PARA (PA)') 16383
# ('NOVA TIMBOTEUA (PA)', 'SANTAREM NOVO (PA)') 16382
# ('OUREM (PA)', 'IRITUIA (PA)') 16381
# ('OUREM (PA)', 'SANTA LUZIA DO PARA (PA)') 16380
# ('OUREM (PA)', 'SAO MIGUEL DO GUAMA (PA)') 16379
# ('OUREM (PA)', 'TRACUATEUA (PA)') 16378
# ('PEIXEBOI (PA)', 'PRIMAVERA (PA)') 16377
# ('PEIXEBOI (PA)', 'SANTAREM NOVO (PA)') 16376
# ('SANTA MARIA DO PARA (PA)', 'CASTANHAL (PA)') 16375
# ('SANTA MARIA DO PARA (PA)', 'IGARAPEACU (PA)') 16374
# ('SANTA MARIA DO PARA (PA)', 'SAO FRANCISCO DO PARA (PA)') 16373
# ('SANTA MARIA DO PARA (PA)', 'SAO MIGUEL DO GUAMA (PA)') 16372
# ('SAO MIGUEL DO GUAMA (PA)', 'CASTANHAL (PA)') 16371
# ('SAO MIGUEL DO GUAMA (PA)', 'INHANGAPI (PA)') 16370
# ('SAO MIGUEL DO GUAMA (PA)', 'IRITUIA (PA)') 16369
# ('TRACUATEUA (PA)', 'QUATIPURU (PA)') 16368
# ('TRACUATEUA (PA)', 'SANTA LUZIA DO PARA (PA)') 16367
# ('SANTA LUZIA DO PARA (PA)', 'GARRAFAO DO NORTE (PA)') 16366
# ('SANTA LUZIA DO PARA (PA)', 'NOVA ESPERANCA DO PIRIA (PA)') 16365
# ('BREJO GRANDE DO ARAGUAIA (PA)', 'PALESTINA DO PARA (PA)') 16364
# ('BREJO GRANDE DO ARAGUAIA (PA)', 'SAO DOMINGOS DO ARAGUAIA (PA)') 16363
# ('BREJO GRANDE DO ARAGUAIA (PA)', 'SAO GERALDO DO ARAGUAIA (PA)') 16362
# ('BREJO GRANDE DO ARAGUAIA (PA)', 'ARAGUATINS (TO)') 16361
# ('PALESTINA DO PARA (PA)', 'SAO GERALDO DO ARAGUAIA (PA)') 16360
# ('PALESTINA DO PARA (PA)', 'ANANAS (TO)') 16359
# ('PALESTINA DO PARA (PA)', 'ARAGUATINS (TO)') 16358
# ('SAO DOMINGOS DO ARAGUAIA (PA)', 'SAO GERALDO DO ARAGUAIA (PA)') 16357
# ('SAO GERALDO DO ARAGUAIA (PA)', 'ELDORADO DO CARAJAS (PA)') 16356
# ('SAO GERALDO DO ARAGUAIA (PA)', 'PICARRA (PA)') 16355
# ('SAO GERALDO DO ARAGUAIA (PA)', 'ANANAS (TO)') 16354
# ('SAO GERALDO DO ARAGUAIA (PA)', 'XAMBIOA (TO)') 16353
# ('ARAGUATINS (TO)', 'ANANAS (TO)') 16352
# ('ARAGUATINS (TO)', 'AUGUSTINOPOLIS (TO)') 16351
# ('ARAGUATINS (TO)', 'AXIXA DO TOCANTINS (TO)') 16350
# ('ARAGUATINS (TO)', 'BURITI DO TOCANTINS (TO)') 16349
# ('ARAGUATINS (TO)', 'SAO BENTO DO TOCANTINS (TO)') 16348
# ('ARAGUATINS (TO)', 'SAO SEBASTIAO DO TOCANTINS (TO)') 16347
# ('GOIANESIA DO PARA (PA)', 'DOM ELISEU (PA)') 16346
# ('GOIANESIA DO PARA (PA)', 'JACUNDA (PA)') 16345
# ('GOIANESIA DO PARA (PA)', 'PARAGOMINAS (PA)') 16344
# ('INHANGAPI (PA)', 'CASTANHAL (PA)') 16343
# ('CACHOEIRA DO PIRIA (PA)', 'NOVA ESPERANCA DO PIRIA (PA)') 16342
# ('CACHOEIRA DO PIRIA (PA)', 'BOA VISTA DO GURUPI (MA)') 16341
# ('CACHOEIRA DO PIRIA (PA)', 'CENTRO NOVO DO MARANHAO (MA)') 16340
# ('CACHOEIRA DO PIRIA (PA)', 'JUNCO DO MARANHAO (MA)') 16339
# ('NOVA ESPERANCA DO PIRIA (PA)', 'GARRAFAO DO NORTE (PA)') 16338
# ('NOVA ESPERANCA DO PIRIA (PA)', 'PARAGOMINAS (PA)') 16337
# ('NOVA ESPERANCA DO PIRIA (PA)', 'CENTRO NOVO DO MARANHAO (MA)') 16336
# ('BOA VISTA DO GURUPI (MA)', 'CARUTAPERA (MA)') 16335
# ('BOA VISTA DO GURUPI (MA)', 'JUNCO DO MARANHAO (MA)') 16334
# ('CENTRO NOVO DO MARANHAO (MA)', 'PARAGOMINAS (PA)') 16333
# ('CENTRO NOVO DO MARANHAO (MA)', 'ULIANOPOLIS (PA)') 16332
# ('CENTRO NOVO DO MARANHAO (MA)', 'BOM JARDIM (MA)') 16331
# ('CENTRO NOVO DO MARANHAO (MA)', 'CENTRO DO GUILHERME (MA)') 16330
# ('CENTRO NOVO DO MARANHAO (MA)', 'ITINGA DO MARANHAO (MA)') 16329
# ('CENTRO NOVO DO MARANHAO (MA)', 'JUNCO DO MARANHAO (MA)') 16328
# ('CENTRO NOVO DO MARANHAO (MA)', 'MARACACUME (MA)') 16327
# ('CENTRO NOVO DO MARANHAO (MA)', 'MARANHAOZINHO (MA)') 16326
# ('CENTRO NOVO DO MARANHAO (MA)', 'NOVA OLINDA DO MARANHAO (MA)') 16325
# ('CENTRO NOVO DO MARANHAO (MA)', 'SAO JOAO DO CARU (MA)') 16324
# ('CENTRO NOVO DO MARANHAO (MA)', 'ZE DOCA (MA)') 16323
# ('JUNCO DO MARANHAO (MA)', 'AMAPA DO MARANHAO (MA)') 16322
# ('JUNCO DO MARANHAO (MA)', 'CARUTAPERA (MA)') 16321
# ('JUNCO DO MARANHAO (MA)', 'MARACACUME (MA)') 16320
# ('COLARES (PA)', 'SALVATERRA (PA)') 16319
# ('COLARES (PA)', 'VIGIA (PA)') 16318
# ('SALVATERRA (PA)', 'SOURE (PA)') 16317
# ('CAMETA (PA)', 'LIMOEIRO DO AJURU (PA)') 16316
# ('PRIMAVERA (PA)', 'QUATIPURU (PA)') 16315
# ('PRIMAVERA (PA)', 'SANTAREM NOVO (PA)') 16314
# ('PRIMAVERA (PA)', 'SAO JOAO DE PIRABAS (PA)') 16313
# ('QUATIPURU (PA)', 'SAO JOAO DE PIRABAS (PA)') 16312
# ('CASTANHAL (PA)', 'SAO CAETANO DE ODIVELAS (PA)') 16311
# ('CASTANHAL (PA)', 'SAO FRANCISCO DO PARA (PA)') 16310
# ('CASTANHAL (PA)', 'TERRA ALTA (PA)') 16309
# ('CASTANHAL (PA)', 'VIGIA (PA)') 16308
# ('SAO CAETANO DE ODIVELAS (PA)', 'CURUCA (PA)') 16307
# ('SAO CAETANO DE ODIVELAS (PA)', 'SAO JOAO DA PONTA (PA)') 16306
# ('SAO CAETANO DE ODIVELAS (PA)', 'TERRA ALTA (PA)') 16305
# ('SAO CAETANO DE ODIVELAS (PA)', 'VIGIA (PA)') 16304
# ('SAO FRANCISCO DO PARA (PA)', 'IGARAPEACU (PA)') 16303
# ('SAO FRANCISCO DO PARA (PA)', 'MARAPANIM (PA)') 16302
# ('SAO FRANCISCO DO PARA (PA)', 'TERRA ALTA (PA)') 16301
# ('TERRA ALTA (PA)', 'CURUCA (PA)') 16300
# ('TERRA ALTA (PA)', 'MARAPANIM (PA)') 16299
# ('TERRA ALTA (PA)', 'SAO JOAO DA PONTA (PA)') 16298

# %%
new_confirmed_avg_df.to_csv("new_confirmed_avg_df_all.csv", sep=";")

# %%
for edge in G.edges(data=True):
    if (temp[temp.city_state == edge[0]].empty) | (
        temp[temp.city_state == edge[1]].empty
    ):
        corr = np.nan
    else:
        confirmed_0 = temp[(temp.city_state == edge[0])].new_confirmed.iloc[0]
        confirmed_1 = temp[(temp.city_state == edge[1])].new_confirmed.iloc[0]
        confirmed_t1_0 = temp[(temp.city_state == edge[0])].new_confirmed_t1.iloc[0]
        confirmed_t1_1 = temp[(temp.city_state == edge[1])].new_confirmed_t1.iloc[0]
        confirmed_t2_0 = temp[(temp.city_state == edge[0])].new_confirmed_t2.iloc[0]
        confirmed_t2_1 = temp[(temp.city_state == edge[1])].new_confirmed_t2.iloc[0]
        confirmed_t3_0 = temp[(temp.city_state == edge[0])].new_confirmed_t3.iloc[0]
        confirmed_t3_1 = temp[(temp.city_state == edge[1])].new_confirmed_t3.iloc[0]
        confirmed_t4_0 = temp[(temp.city_state == edge[0])].new_confirmed_t4.iloc[0]
        confirmed_t4_1 = temp[(temp.city_state == edge[1])].new_confirmed_t5.iloc[0]
        confirmed_t5_0 = temp[(temp.city_state == edge[0])].new_confirmed_t5.iloc[0]
        confirmed_t5_1 = temp[(temp.city_state == edge[1])].new_confirmed_t5.iloc[0]
        confirmed_t6_0 = temp[(temp.city_state == edge[0])].new_confirmed_t6.iloc[0]
        confirmed_t6_1 = temp[(temp.city_state == edge[1])].new_confirmed_t6.iloc[0]

        t0_0 = [
            confirmed_t5_0,
            confirmed_t4_0,
            confirmed_t3_0,
            confirmed_t2_0,
            confirmed_t1_0,
            confirmed_0,
        ]
        # t1_0 = [confirmed_t6_0,confirmed_t5_0,confirmed_t4_0,confirmed_t3_0,confirmed_t2_0,confirmed_t1_0]

        t0_1 = [
            confirmed_t5_1,
            confirmed_t4_1,
            confirmed_t3_1,
            confirmed_t2_1,
            confirmed_t1_1,
            confirmed_1,
        ]
        # t1_1 = [confirmed_t6_1,confirmed_t5_1,confirmed_t4_1,confirmed_t3_1,confirmed_t2_1,confirmed_t1_1]

        try:
            corr_t0, p_t0 = pearsonr(t0_0, t0_1)
        except:
            corr_t0 = np.nan
        # try: corr_t1, p_t1 = pearsonr(t1_0, t1_1)
        # except: corr_t1 = np.nan
        # corr = abs(corr_t0) - abs(corr_t1)
        corr = corr_t0
    print(edge)

# %%
import matplotlib as mp
import matplotlib.cm as cm

pearson = [x[2]["pearson"] for x in list(G.edges(data=True))]

minima = min(pearson)
maxima = max(pearson)

norm = mp.colors.Normalize(vmin=minima, vmax=maxima, clip=True)
mapper = cm.ScalarMappable(norm=norm, cmap=plt.cm.BrBG)

color_list = [mapper.to_rgba(v) for v in pearson]
alpha_list = [0.5 if x[2]["aereo"] == "sim" else 0.5 for x in list(G.edges(data=True))]
linestyle_list = [
    "dotted" if x[2]["aereo"] == "sim" else "solid" for x in list(G.edges(data=True))
]

capital = nx.get_node_attributes(G, "capital")
region = nx.get_node_attributes(G, "region")
node_size_list = [15 if x == "sim" else 10 for x in list(capital.values())]
node_alpha_list = [0.6 if x == "sim" else 0.4 for x in list(capital.values())]
node_color_list = "gray"

labels = {}
for node in G.nodes(data=True):
    if node[1]["capital"] == "sim":
        labels[node[0]] = node[0]

positions = nx.get_node_attributes(G, "pos")
# Produce the curves
curves = curved_edges(G, positions)
lc = LineCollection(
    curves, color=color_list, alpha=alpha_list, linestyle=linestyle_list
)

size = nx.get_node_attributes(G, "population")
size_list = [v for v in size.values()]
size_norm = [float(i) / max(size_list) for i in size_list]

plt.figure(figsize=(20, 20))
nx.draw_networkx_nodes(
    G,
    positions,
    node_size=node_size_list,
    alpha=node_alpha_list,
    node_color=node_color_list,
)
plt.gca().add_collection(lc)
plt.tick_params(
    axis="both",
    which="both",
    bottom=False,
    left=False,
    labelbottom=False,
    labelleft=False,
)
# nx.draw_networkx_labels(G, positions, labels, font_size=12, font_color="black")
plt.savefig("grafo_cidades_aeroportos_202040.png", transparent=False)
plt.show()

# %%
minimum_spanning_tree = tree.mst.minimum_spanning_tree(
    G, weight="pearson", ignore_nan=True
)
sum_ = sum(list(nx.get_edge_attributes(minimum_spanning_tree, "pearson").values()))
print("Sum:", sum_)
# Sum: -517.7498406040883 202020
# Sum: -806.0413886847555 202022
# Sum: -1056.9493846100775 202025
# Sum: -1322.9335498411547 202031
# Sum: -1362.3329650691155 202033
# Sum: -1275.7802168555108 202035
# Sum: -1332.737400610826 202036
# Sum: -1232.9998790140364 202040
# Sum: -1225.2711675299283 202045
# Sum: -1177.700229849171 202050

# %%
1 + np.exp(-1 * sum_)
# 7.17627017190965e+224 202020
# inf 202022
# inf 202025
# inf 202031
# inf 202033
# 1.1934680253072109e+125 202036
# inf 202045

# %%
sum_ = -806.0413886847555

# %%
def infection_yes_no(input_network, casosDf, vis=False, title=""):
    print("Replicating infection.")

    network = input_network.copy()
    positions = nx.get_node_attributes(network, "pos")
    curves = curved_edges(network, positions)

    # Set the default to susceptable
    sys.stdout.flush()
    for node in network.nodes():
        nx.set_node_attributes(network, values={node: "s"}, name="status")
        nx.set_node_attributes(network, values={node: "#A6A6A6"}, name="color")
        nx.set_node_attributes(network, values={node: 0.4}, name="alpha")
    for edge in network.edges(data=True):
        nx.set_edge_attributes(network, {(edge[0], edge[1]): "#A6A6A6"}, "color")
    if vis:
        pos = nx.get_node_attributes(network, "pos")

    epi_weeks = sorted(list(set(casosDf.epidemiological_week.tolist())))

    for week in epi_weeks:
        inicial, infectado = 0, 0
        weekDf = casosDf[casosDf.epidemiological_week == week]
        cities = list(set(weekDf.city_state.tolist()))
        for city in cities:
            nx.set_node_attributes(network, {city: "i"}, "status")
            nx.set_node_attributes(
                network, {city: (0.888292, 0.40830288, 0.36223756)}, "color"
            )
            nx.set_node_attributes(network, {city: 0.8}, "alpha")
        for edge in network.edges(data=True):
            if (
                network.nodes[edge[0]]["status"] == "i"
                and network.nodes[edge[1]]["status"] == "i"
            ):
                nx.set_edge_attributes(
                    network,
                    {(edge[0], edge[1]): (0.888292, 0.40830288, 0.36223756)},
                    "color",
                )

        for node in network.nodes():
            status = network.nodes[node]["status"]
            color = network.nodes[node]["color"]
            if status == "s":
                inicial += 1
            elif status == "i":
                infectado += 1
        print(
            "{0}, {1}, {2}".format(
                week, inicial / len(network.nodes()), infectado / len(network.nodes())
            )
        )

        if inicial == 0:
            break

        if vis:
            visualize_curved_edges(network, title, pos, curves)

    print(
        "\t----------\n\tS: {0}, I: {1}, {2}".format(
            inicial, infectado, infectado / len(network.nodes())
        )
    )

    return {"Suscceptable": inicial, "Infected": infectado}

# %%
def infection_cases(
    input_network,
    casosDf,
    DELAY=0,
    vis=False,
    file_name="sir.csv",
    title="",
    RECALCULATE=True,
):
    print("Replicating infection.")

    network = input_network.copy()
    positions = nx.get_node_attributes(network, "pos")
    curves = curved_edges(network, positions)

    # Set the default to susceptable
    sys.stdout.flush()
    for node in network.nodes():
        nx.set_node_attributes(network, values={node: "s"}, name="status")
        nx.set_node_attributes(network, values={node: "#A6A6A6"}, name="color")
        nx.set_node_attributes(network, values={node: 0.4}, name="alpha")
    for edge in network.edges(data=True):
        nx.set_edge_attributes(network, {(edge[0], edge[1]): "#A6A6A6"}, "color")

    if vis:
        pos = nx.get_node_attributes(network, "pos")

    epi_weeks = sorted(list(set(casosDf.epidemiological_week.tolist())))
    palette = sns.color_palette("flare")
    # Iterate through the evolution of the disease.
    i = 0
    for week in epi_weeks:
        i = i + 1
        print(i)
        # Create variables to hold the outcomes as they happen
        S, queda, estab, aumento = 0, 0, 0, 0

        casosWeekDf = casosDf[casosDf.epidemiological_week == week]
        cities = list(set(casosWeekDf.city_state.tolist()))

        for city in cities:
            new_per = casosWeekDf[
                casosWeekDf.city_state == city
            ].new_deaths_percent.values[0]
            if new_per < -0.01:
                nx.set_node_attributes(network, {city: "em queda"}, "status")
                nx.set_node_attributes(network, {city: palette[4]}, "color")
                nx.set_node_attributes(network, {city: 0.7}, "alpha")

            elif new_per < 0.10:
                nx.set_node_attributes(network, {city: "estabilidade"}, "status")
                nx.set_node_attributes(network, {city: palette[2]}, "color")
                nx.set_node_attributes(network, {city: 0.7}, "alpha")

            else:
                nx.set_node_attributes(network, {city: "aumento"}, "status")
                nx.set_node_attributes(network, {city: palette[0]}, "color")
                nx.set_node_attributes(network, {city: 0.8}, "alpha")

        # Loop twice to prevent bias.
        for edge in network.edges(data=True):
            if (casosWeekDf[(casosWeekDf.city_state == edge[0])].empty) | (
                casosWeekDf[(casosWeekDf.city_state == edge[1])].empty
            ):
                pass
            else:
                confirmed_0 = casosWeekDf[
                    (casosWeekDf.city_state == edge[0])
                ].new_confirmed.iloc[0]
                confirmed_1 = casosWeekDf[
                    (casosWeekDf.city_state == edge[1])
                ].new_confirmed.iloc[0]
                last_week_confirmed_0 = casosWeekDf[
                    (casosWeekDf.city_state == edge[0])
                ].last_week_new_confirmed.iloc[0]
                last_week_confirmed_1 = casosWeekDf[
                    (casosWeekDf.city_state == edge[1])
                ].last_week_new_confirmed.iloc[0]
                corr, p = pearsonr(
                    [last_week_confirmed_0, confirmed_0],
                    [last_week_confirmed_1, confirmed_1],
                )
                nx.set_edge_attributes(network, {(edge[0], edge[1]): corr}, "pearson")

            if (
                network.nodes[edge[0]]["status"] == "i"
                and network.nodes[edge[1]]["status"] == "i"
            ):
                nx.set_edge_attributes(
                    network,
                    {(edge[0], edge[1]): (0.888292, 0.40830288, 0.36223756)},
                    "color",
                )

        minimum_spanning_tree = tree.mst.minimum_spanning_tree(
            network, weight="pearson"
        )
        sum_ = sum(
            list(nx.get_edge_attributes(minimum_spanning_tree, "pearson").values())
        )
        print("sum:", sum_)

        for node in network.nodes():
            status = network.nodes[node]["status"]
            color = network.nodes[node]["color"]

            if status == "s":
                S += 1
            if status == "em queda":
                queda += 1
            if status == "estabilidade":
                estab += 1
            elif status == "aumento":
                aumento += 1

        print(
            "Semana: {0},Suscetivel: {1},Em queda: {2},Estabilidade: {3},Aumento: {4}".format(
                week, S, queda, estab, aumento
            )
        )

        if vis:
            visualize_curved_edges(network, title, pos, curves)

    print("\t----------\n\tS: {0}, I: {1}, R: {2}".format(S, queda, aumento))

    return {"Suscceptable": S, "Infected": queda, "Recovered": aumento}

# %%
from scipy.stats import pearsonr
from networkx.algorithms import tree

# minimum_spanning_tree_G = tree.mst.minimum_spanning_tree(G, weight="distance")
# G = create_network('grafo_cidades_aeroportos.gexf')
# for edge in G.edges(data=True):
#    print(edge[0],edge[1])
temp = casosDf.epidemiological_week[0]
temp2 = casosDf[casosDf.epidemiological_week == temp]
len(temp2)

# %%
def visualize_curved_edges(network, title, pos, curves):
    """
    Visualize the network given an array of posisitons.
    """
    print("-- Starting to Visualize --")

    colors = []
    alphas = []
    edge_colors = []
    for node in network.nodes():
        colors.append(network.nodes[node]["color"])
        alphas.append(network.nodes[node]["alpha"])
    for edge in network.edges(data=True):
        edge_colors.append(network[edge[0]][edge[1]]["color"])

    positions = nx.get_node_attributes(network, "pos")
    lc = LineCollection(curves, color=edge_colors, alpha=0.1)
    capital = nx.get_node_attributes(network, "capital")
    sizes = [100 if x == "sim" else 15 for x in list(capital.values())]
    # Plot
    fig, ax = plt.subplots(figsize=(8, 8))
    nx.draw_networkx_nodes(
        network, positions, node_size=sizes, alpha=alphas, node_color=colors, ax=ax
    )
    plt.gca().add_collection(lc)
    plt.tick_params(
        axis="both",
        which="both",
        bottom=False,
        left=False,
        labelbottom=False,
        labelleft=False,
    )

    number_files = str(len(os.listdir()))
    while len(number_files) < 3:
        number_files = "0" + number_files

    plt.show()

# %%
def visualize(network, title, pos):
    """
    Visualize the network given an array of posisitons.
    """
    print("-- Starting to Visualize --")

    colors = []
    i_edge_colors = []
    d_edge_colors = []
    default = []
    infected = []
    for node in network.nodes():
        colors.append(network.nodes[node]["color"])
    for i, j in network.edges():
        color = network.nodes[i]["color"]
        alpha = 0.75
        if color == (0.42355299, 0.16934709, 0.42581586) or color == (
            0.48942421,
            0.72854938,
            0.56751036,
        ):
            color = "#A6A6A6"
            default.append((i, j))
            d_edge_colors.append(color)
        else:
            color = "#A6A6A6"  # 29A229"
            infected.append((i, j))
            i_edge_colors.append(color)

    fig, ax = plt.subplots(figsize=(10, 10))

    # Fist pass - Gray lines
    nx.draw_networkx_edges(
        network,
        pos,
        connectionstyle="arc3,rad=0.9",
        edgelist=default,
        width=0.5,
        edge_color=d_edge_colors,
        alpha=0.5,
        arrows=False,
        ax=ax,
    )

    # Second Pass - Colored lines
    nx.draw_networkx_edges(
        network,
        pos,
        connectionstyle="arc3,rad=0.9",
        edgelist=infected,
        width=0.5,
        edge_color=i_edge_colors,
        alpha=0.75,
        arrows=False,
        ax=ax,
    )

    positions = nx.get_node_attributes(G, "pos")
    nx.draw_networkx_nodes(
        network,
        pos,
        linewidths=0.5,
        node_size=15,
        alpha=0.5,
        # with_labels=False,
        node_color=colors,
        ax=ax,
    )

    # Adjust the plot limits
    cut = 1.05
    xmax = cut * max(xx for xx, yy in pos.values())
    xmin = min(xx for xx, yy in pos.values())
    xmin = xmin - (cut * xmin)

    ymax = cut * max(yy for xx, yy in pos.values())
    ymin = (cut) * min(yy for xx, yy in pos.values())
    ymin = ymin - (cut * ymin)

    number_files = str(len(os.listdir()))
    while len(number_files) < 3:
        number_files = "0" + number_files

    plt.show()
    plt.close()

# %%
try:
    G = create_network(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/grafo_cidades_aeroportos.gexf"
    )
except:
    G = create_network("grafo_cidades_aeroportos.gexf")
infection_yes_no(
    G,
    casosGroupDf,
    vis=True,
    title="title",
)

# %%
try:
    G = create_network(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/grafo_cidades_aeroportos.gexf"
    )
except:
    G = create_network("grafo_cidades_aeroportos.gexf")
infection_cases(
    G,
    casosGroupDf,
    vis=True,
    title="title",
)

# %%
casosGroupDf["state"] = casosGroupDf.city_state.str.get(
    -3
) + casosGroupDf.city_state.str.get(-2)

# %%
try:
    G = create_network(
        "/content/gdrive/MyDrive/Graph Theory for Machine Learning/gcavali-repo-main/grafo_cidades.gexf"
    )
except:
    G = create_network("grafo_cidades.gexf")
G.remove_edges_from(nx.selfloop_edges(G))
selected_nodes = [n for n, v in G.nodes(data=True) if n[-3:-1] == "SP"]
G_sub = G.subgraph(selected_nodes)
infection_yes_no(
    G_sub,
    casosGroupDf[casosGroupDf.state == "SP"],
    vis=True,
    title="title",
)

# %%
infection_cases(
    G_sub, casosGroupDf[casosGroupDf.state == "SP"], vis=True, title="title", DELAY=0
)
